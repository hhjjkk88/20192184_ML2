# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
train_data1 = pd.read_csv('data/train_data/train_task_1_2.csv')
val_data1 = pd.read_csv('data/test_data/test_public_answers_task_1.csv')
test_data1 = pd.read_csv('data/test_data/test_private_answers_task_1.csv')
m_data_a1 = pd.read_csv('data/metadata/answer_metadata_task_1_2.csv')
m_data_q1 = pd.read_csv('data/metadata/question_metadata_task_1_2.csv')
m_data_s1 = pd.read_csv('data/metadata/student_metadata_task_1_2.csv')

# %%
train_data1.head()
# Out:
#    QuestionId  UserId  AnswerId  IsCorrect  CorrectAnswer  AnswerValue
# 0       16997   65967  12453206          0              4            2
# 1       16531   62121  15686710          1              1            1
# 2       15911   50013  13598796          0              3            1
# 3        1701  104909  10511925          0              4            3
# 4       22896   21748    941747          0              1            4

# %%
train_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15867850 entries, 0 to 15867849
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   QuestionId     int64
#  1   UserId         int64
#  2   AnswerId       int64
#  3   IsCorrect      int64
#  4   CorrectAnswer  int64
#  5   AnswerValue    int64
# dtypes: int64(6)
# memory usage: 726.4 MB

# %%
correlation_matrix = train_data1.corr()
correlation_with_target = correlation_matrix['IsCorrect'].sort_values(ascending=False)
correlation_matrix
# Out:
#                QuestionId    UserId  AnswerId  IsCorrect  CorrectAnswer  \
# QuestionId       1.000000 -0.000170 -0.000150   0.000642       0.008882
# UserId          -0.000170  1.000000 -0.000060   0.002105      -0.000090
# AnswerId        -0.000150 -0.000060  1.000000  -0.000450       0.000100
# IsCorrect        0.000642  0.002105 -0.000450   1.000000      -0.010002
# CorrectAnswer    0.008882 -0.000090  0.000100  -0.010002       1.000000
# AnswerValue      0.001107  0.000228 -0.000011   0.006604       0.528478
#
#                AnswerValue
# QuestionId        0.001107
# UserId            0.000228
# AnswerId         -0.000011
# IsCorrect         0.006604
# CorrectAnswer     0.528478
# AnswerValue       1.000000

# %%
train_data1.columns
# Out:
# Index(['QuestionId', 'UserId', 'AnswerId', 'IsCorrect', 'CorrectAnswer',
#        'AnswerValue'],
#       dtype='object')

# %%
X_train = train_data1.drop(['IsCorrect','AnswerValue','CorrectAnswer'],axis=1)
y_train= train_data1['IsCorrect']
X_test = test_data1.drop(['IsCorrect'],axis=1)
y_test = test_data1['IsCorrect']

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor, LGBMClassifier, Booster
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, PoissonRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X,y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
# Scale the features using a MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from catboost import CatBoostRegressor
from sklearn.ensemble import VotingRegressor

# %%
# Initialize the individual models
cb_model = CatBoostRegressor(random_state = 42)
gb_model = GradientBoostingRegressor(learning_rate=0.2,n_estimators=200,random_state = 42)
lgb_model = lgb.LGBMRegressor(n_estimators = 400, learning_rate = 0.2, random_state = 42)

# Initialize the ensemble model
ensemble_model = VotingRegressor(estimators=[("cb", cb_model), ("gb", gb_model), ("lgb", lgb_model)])

# Fit the ensemble model to the scaled training data
ensemble_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled testing data
y_pred = ensemble_model.predict(X_test_scaled)

# Evaluate the performance of the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.2f}")
# Out:
# Learning rate set to 0.188739
# 0:	learn: 0.4791141	total: 4.39s	remaining: 1h 13m 9s
# 1:	learn: 0.4791044	total: 5.12s	remaining: 42m 33s
# 2:	learn: 0.4790996	total: 5.77s	remaining: 31m 56s
# 3:	learn: 0.4790956	total: 6.51s	remaining: 27m
# 4:	learn: 0.4790921	total: 7.28s	remaining: 24m 8s
# 5:	learn: 0.4790881	total: 7.84s	remaining: 21m 39s
# 6:	learn: 0.4790833	total: 8.5s	remaining: 20m 5s
# 7:	learn: 0.4790763	total: 9.13s	remaining: 18m 52s
# 8:	learn: 0.4790729	total: 9.74s	remaining: 17m 52s
# 9:	learn: 0.4790686	total: 10.3s	remaining: 17m 1s
# 10:	learn: 0.4790599	total: 10.9s	remaining: 16m 22s
# 11:	learn: 0.4790574	total: 11.6s	remaining: 15m 51s
# 12:	learn: 0.4790552	total: 12.2s	remaining: 15m 29s
# 13:	learn: 0.4790520	total: 12.9s	remaining: 15m 6s
# 14:	learn: 0.4790495	total: 13.5s	remaining: 14m 47s
# 15:	learn: 0.4790478	total: 14.1s	remaining: 14m 28s
# 16:	learn: 0.4790444	total: 14.7s	remaining: 14m 8s
# 17:	learn: 0.4790408	total: 15.4s	remaining: 14m
# 18:	learn: 0.4790367	total: 16.1s	remaining: 13m 50s
# 19:	learn: 0.4790340	total: 16.7s	remaining: 13m 38s
# 20:	learn: 0.4790323	total: 17.3s	remaining: 13m 28s
# 21:	learn: 0.4790283	total: 18s	remaining: 13m 19s
# 22:	learn: 0.4790250	total: 18.6s	remaining: 13m 11s
# 23:	learn: 0.4790184	total: 19.3s	remaining: 13m 4s
# 24:	learn: 0.4790128	total: 19.9s	remaining: 12m 57s
# 25:	learn: 0.4790099	total: 20.5s	remaining: 12m 49s
# 26:	learn: 0.4790045	total: 21.2s	remaining: 12m 42s
# 27:	learn: 0.4789991	total: 21.9s	remaining: 12m 38s
# 28:	learn: 0.4789953	total: 22.6s	remaining: 12m 36s
# 29:	learn: 0.4789926	total: 23.3s	remaining: 12m 32s
# 30:	learn: 0.4789892	total: 24s	remaining: 12m 29s
# 31:	learn: 0.4789868	total: 24.6s	remaining: 12m 24s
# 32:	learn: 0.4789849	total: 25.3s	remaining: 12m 21s
# 33:	learn: 0.4789830	total: 25.9s	remaining: 12m 17s
# 34:	learn: 0.4789819	total: 26.6s	remaining: 12m 13s
# 35:	learn: 0.4789799	total: 27.3s	remaining: 12m 9s
# 36:	learn: 0.4789773	total: 27.9s	remaining: 12m 5s
# 37:	learn: 0.4789722	total: 28.5s	remaining: 12m 1s
# 38:	learn: 0.4789711	total: 29.1s	remaining: 11m 57s
# 39:	learn: 0.4789647	total: 29.9s	remaining: 11m 56s
# 40:	learn: 0.4789599	total: 30.5s	remaining: 11m 53s
# 41:	learn: 0.4789571	total: 31.2s	remaining: 11m 51s
# 42:	learn: 0.4789558	total: 31.9s	remaining: 11m 50s
# 43:	learn: 0.4789510	total: 32.7s	remaining: 11m 50s
# 44:	learn: 0.4789482	total: 33.3s	remaining: 11m 47s
# 45:	learn: 0.4789442	total: 34s	remaining: 11m 46s
# 46:	learn: 0.4789428	total: 34.8s	remaining: 11m 45s
# 47:	learn: 0.4789408	total: 35.5s	remaining: 11m 44s
# 48:	learn: 0.4789363	total: 36.3s	remaining: 11m 44s
# 49:	learn: 0.4789339	total: 37s	remaining: 11m 43s
# 50:	learn: 0.4789302	total: 37.8s	remaining: 11m 42s
# 51:	learn: 0.4789274	total: 38.4s	remaining: 11m 39s
# 52:	learn: 0.4789261	total: 39.1s	remaining: 11m 38s
# 53:	learn: 0.4789242	total: 39.8s	remaining: 11m 37s
# 54:	learn: 0.4789227	total: 40.5s	remaining: 11m 35s
# 55:	learn: 0.4789216	total: 41.1s	remaining: 11m 33s
# 56:	learn: 0.4789193	total: 41.9s	remaining: 11m 32s
# 57:	learn: 0.4789181	total: 42.6s	remaining: 11m 31s
# 58:	learn: 0.4789174	total: 43.2s	remaining: 11m 29s
# 59:	learn: 0.4789154	total: 44s	remaining: 11m 29s
# 60:	learn: 0.4789141	total: 44.7s	remaining: 11m 28s
# 61:	learn: 0.4789115	total: 45.4s	remaining: 11m 26s
# 62:	learn: 0.4789111	total: 46.1s	remaining: 11m 26s
# 63:	learn: 0.4789096	total: 46.8s	remaining: 11m 24s
# 64:	learn: 0.4789043	total: 47.5s	remaining: 11m 23s
# 65:	learn: 0.4788999	total: 48.2s	remaining: 11m 22s
# 66:	learn: 0.4788973	total: 48.9s	remaining: 11m 20s
# 67:	learn: 0.4788962	total: 49.6s	remaining: 11m 19s
# 68:	learn: 0.4788948	total: 50.3s	remaining: 11m 18s
# 69:	learn: 0.4788916	total: 51.2s	remaining: 11m 19s
# 70:	learn: 0.4788884	total: 51.9s	remaining: 11m 19s
# 71:	learn: 0.4788868	total: 52.6s	remaining: 11m 18s
# 72:	learn: 0.4788862	total: 53.3s	remaining: 11m 16s
# 73:	learn: 0.4788847	total: 54s	remaining: 11m 15s
# 74:	learn: 0.4788812	total: 54.6s	remaining: 11m 13s
# 75:	learn: 0.4788801	total: 55.3s	remaining: 11m 12s
# 76:	learn: 0.4788774	total: 56.1s	remaining: 11m 11s
# 77:	learn: 0.4788758	total: 56.8s	remaining: 11m 11s
# 78:	learn: 0.4788745	total: 57.5s	remaining: 11m 10s
# 79:	learn: 0.4788738	total: 58.2s	remaining: 11m 9s
# 80:	learn: 0.4788705	total: 58.9s	remaining: 11m 8s
# 81:	learn: 0.4788678	total: 59.6s	remaining: 11m 7s
# 82:	learn: 0.4788672	total: 1m	remaining: 11m 6s
# 83:	learn: 0.4788634	total: 1m	remaining: 11m 5s
# 84:	learn: 0.4788623	total: 1m 1s	remaining: 11m 4s
# 85:	learn: 0.4788612	total: 1m 2s	remaining: 11m 2s
# 86:	learn: 0.4788599	total: 1m 2s	remaining: 11m 1s
# 87:	learn: 0.4788587	total: 1m 3s	remaining: 10m 59s
# 88:	learn: 0.4788573	total: 1m 4s	remaining: 10m 58s
# 89:	learn: 0.4788541	total: 1m 5s	remaining: 10m 57s
# 90:	learn: 0.4788532	total: 1m 5s	remaining: 10m 56s
# 91:	learn: 0.4788519	total: 1m 6s	remaining: 10m 54s
# 92:	learn: 0.4788489	total: 1m 7s	remaining: 10m 53s
# 93:	learn: 0.4788457	total: 1m 7s	remaining: 10m 52s
# 94:	learn: 0.4788425	total: 1m 8s	remaining: 10m 51s
# 95:	learn: 0.4788411	total: 1m 9s	remaining: 10m 50s
# 96:	learn: 0.4788367	total: 1m 9s	remaining: 10m 49s
# 97:	learn: 0.4788327	total: 1m 10s	remaining: 10m 51s
# 98:	learn: 0.4788292	total: 1m 11s	remaining: 10m 51s
# 99:	learn: 0.4788282	total: 1m 12s	remaining: 10m 50s
# 100:	learn: 0.4788260	total: 1m 12s	remaining: 10m 49s
# 101:	learn: 0.4788245	total: 1m 13s	remaining: 10m 48s
# 102:	learn: 0.4788237	total: 1m 14s	remaining: 10m 46s
# 103:	learn: 0.4788217	total: 1m 15s	remaining: 10m 46s
# 104:	learn: 0.4788190	total: 1m 15s	remaining: 10m 45s
# 105:	learn: 0.4788183	total: 1m 16s	remaining: 10m 45s
# 106:	learn: 0.4788154	total: 1m 17s	remaining: 10m 45s
# 107:	learn: 0.4788144	total: 1m 18s	remaining: 10m 44s
# 108:	learn: 0.4788134	total: 1m 18s	remaining: 10m 43s
# 109:	learn: 0.4788108	total: 1m 19s	remaining: 10m 43s
# 110:	learn: 0.4788099	total: 1m 20s	remaining: 10m 42s
# 111:	learn: 0.4788085	total: 1m 20s	remaining: 10m 41s
# 112:	learn: 0.4788070	total: 1m 21s	remaining: 10m 40s
# 113:	learn: 0.4788052	total: 1m 22s	remaining: 10m 39s
# 114:	learn: 0.4788044	total: 1m 22s	remaining: 10m 37s
# 115:	learn: 0.4788031	total: 1m 23s	remaining: 10m 36s
# 116:	learn: 0.4788026	total: 1m 24s	remaining: 10m 35s
# 117:	learn: 0.4788004	total: 1m 24s	remaining: 10m 34s
# 118:	learn: 0.4787991	total: 1m 25s	remaining: 10m 34s
# 119:	learn: 0.4787983	total: 1m 26s	remaining: 10m 33s
# 120:	learn: 0.4787956	total: 1m 27s	remaining: 10m 33s
# 121:	learn: 0.4787929	total: 1m 27s	remaining: 10m 32s
# 122:	learn: 0.4787920	total: 1m 28s	remaining: 10m 31s
# 123:	learn: 0.4787904	total: 1m 29s	remaining: 10m 30s
# 124:	learn: 0.4787896	total: 1m 29s	remaining: 10m 29s
# 125:	learn: 0.4787874	total: 1m 30s	remaining: 10m 28s
# 126:	learn: 0.4787866	total: 1m 31s	remaining: 10m 26s
# 127:	learn: 0.4787858	total: 1m 31s	remaining: 10m 25s
# 128:	learn: 0.4787838	total: 1m 32s	remaining: 10m 24s
# 129:	learn: 0.4787818	total: 1m 33s	remaining: 10m 23s
# 130:	learn: 0.4787813	total: 1m 33s	remaining: 10m 22s
# 131:	learn: 0.4787795	total: 1m 34s	remaining: 10m 21s
# 132:	learn: 0.4787775	total: 1m 35s	remaining: 10m 21s
# 133:	learn: 0.4787757	total: 1m 36s	remaining: 10m 20s
# 134:	learn: 0.4787741	total: 1m 36s	remaining: 10m 19s
# 135:	learn: 0.4787734	total: 1m 37s	remaining: 10m 17s
# 136:	learn: 0.4787713	total: 1m 37s	remaining: 10m 16s
# 137:	learn: 0.4787701	total: 1m 38s	remaining: 10m 15s
# 138:	learn: 0.4787680	total: 1m 39s	remaining: 10m 14s
# 139:	learn: 0.4787670	total: 1m 39s	remaining: 10m 13s
# 140:	learn: 0.4787647	total: 1m 40s	remaining: 10m 12s
# 141:	learn: 0.4787644	total: 1m 41s	remaining: 10m 10s
# 142:	learn: 0.4787625	total: 1m 41s	remaining: 10m 9s
# 143:	learn: 0.4787614	total: 1m 42s	remaining: 10m 8s
# 144:	learn: 0.4787588	total: 1m 43s	remaining: 10m 8s
# 145:	learn: 0.4787558	total: 1m 43s	remaining: 10m 7s
# 146:	learn: 0.4787554	total: 1m 44s	remaining: 10m 6s
# 147:	learn: 0.4787544	total: 1m 45s	remaining: 10m 5s
# 148:	learn: 0.4787535	total: 1m 45s	remaining: 10m 4s
# 149:	learn: 0.4787527	total: 1m 46s	remaining: 10m 3s
# 150:	learn: 0.4787512	total: 1m 47s	remaining: 10m 2s
# 151:	learn: 0.4787501	total: 1m 47s	remaining: 10m 1s
# 152:	learn: 0.4787487	total: 1m 48s	remaining: 10m
# 153:	learn: 0.4787482	total: 1m 49s	remaining: 9m 59s
# 154:	learn: 0.4787460	total: 1m 49s	remaining: 9m 58s
# 155:	learn: 0.4787452	total: 1m 50s	remaining: 9m 57s
# 156:	learn: 0.4787419	total: 1m 51s	remaining: 9m 56s
# 157:	learn: 0.4787390	total: 1m 51s	remaining: 9m 55s
# 158:	learn: 0.4787375	total: 1m 52s	remaining: 9m 54s
# 159:	learn: 0.4787363	total: 1m 53s	remaining: 9m 53s
# 160:	learn: 0.4787348	total: 1m 53s	remaining: 9m 52s
# 161:	learn: 0.4787335	total: 1m 54s	remaining: 9m 51s
# 162:	learn: 0.4787323	total: 1m 55s	remaining: 9m 51s
# 163:	learn: 0.4787313	total: 1m 55s	remaining: 9m 50s
# 164:	learn: 0.4787307	total: 1m 56s	remaining: 9m 49s
# 165:	learn: 0.4787293	total: 1m 57s	remaining: 9m 48s
# 166:	learn: 0.4787284	total: 1m 57s	remaining: 9m 46s
# 167:	learn: 0.4787271	total: 1m 58s	remaining: 9m 45s
# 168:	learn: 0.4787264	total: 1m 58s	remaining: 9m 44s
# 169:	learn: 0.4787260	total: 1m 59s	remaining: 9m 44s
# 170:	learn: 0.4787244	total: 2m	remaining: 9m 43s
# 171:	learn: 0.4787238	total: 2m	remaining: 9m 41s
# 172:	learn: 0.4787228	total: 2m 1s	remaining: 9m 40s
# 173:	learn: 0.4787220	total: 2m 2s	remaining: 9m 39s
# 174:	learn: 0.4787217	total: 2m 2s	remaining: 9m 38s
# 175:	learn: 0.4787200	total: 2m 3s	remaining: 9m 37s
# 176:	learn: 0.4787192	total: 2m 4s	remaining: 9m 36s
# 177:	learn: 0.4787173	total: 2m 4s	remaining: 9m 36s
# 178:	learn: 0.4787169	total: 2m 5s	remaining: 9m 35s
# 179:	learn: 0.4787153	total: 2m 6s	remaining: 9m 34s
# 180:	learn: 0.4787145	total: 2m 6s	remaining: 9m 33s
# 181:	learn: 0.4787143	total: 2m 7s	remaining: 9m 32s
# 182:	learn: 0.4787138	total: 2m 8s	remaining: 9m 31s
# 183:	learn: 0.4787125	total: 2m 8s	remaining: 9m 30s
# 184:	learn: 0.4787111	total: 2m 9s	remaining: 9m 30s
# 185:	learn: 0.4787105	total: 2m 10s	remaining: 9m 29s
# 186:	learn: 0.4787092	total: 2m 10s	remaining: 9m 28s
# 187:	learn: 0.4787084	total: 2m 11s	remaining: 9m 27s
# 188:	learn: 0.4787066	total: 2m 12s	remaining: 9m 26s
# 189:	learn: 0.4787056	total: 2m 12s	remaining: 9m 25s
# 190:	learn: 0.4787050	total: 2m 13s	remaining: 9m 24s
# 191:	learn: 0.4787046	total: 2m 13s	remaining: 9m 23s
# 192:	learn: 0.4787037	total: 2m 14s	remaining: 9m 22s
# 193:	learn: 0.4787028	total: 2m 15s	remaining: 9m 21s
# 194:	learn: 0.4787025	total: 2m 15s	remaining: 9m 20s
# 195:	learn: 0.4787010	total: 2m 16s	remaining: 9m 19s
# 196:	learn: 0.4787001	total: 2m 17s	remaining: 9m 19s
# 197:	learn: 0.4786994	total: 2m 17s	remaining: 9m 18s
# 198:	learn: 0.4786966	total: 2m 18s	remaining: 9m 17s
# 199:	learn: 0.4786954	total: 2m 19s	remaining: 9m 17s
# 200:	learn: 0.4786950	total: 2m 19s	remaining: 9m 16s
# 201:	learn: 0.4786944	total: 2m 20s	remaining: 9m 15s
# 202:	learn: 0.4786941	total: 2m 21s	remaining: 9m 14s
# 203:	learn: 0.4786927	total: 2m 21s	remaining: 9m 13s
# 204:	learn: 0.4786919	total: 2m 22s	remaining: 9m 12s
# 205:	learn: 0.4786907	total: 2m 23s	remaining: 9m 11s
# 206:	learn: 0.4786889	total: 2m 23s	remaining: 9m 10s
# 207:	learn: 0.4786883	total: 2m 24s	remaining: 9m 9s
# 208:	learn: 0.4786876	total: 2m 25s	remaining: 9m 9s
# 209:	learn: 0.4786865	total: 2m 25s	remaining: 9m 8s
# 210:	learn: 0.4786854	total: 2m 26s	remaining: 9m 7s
# 211:	learn: 0.4786844	total: 2m 27s	remaining: 9m 7s
# 212:	learn: 0.4786840	total: 2m 27s	remaining: 9m 6s
# 213:	learn: 0.4786831	total: 2m 28s	remaining: 9m 5s
# 214:	learn: 0.4786826	total: 2m 29s	remaining: 9m 4s
# 215:	learn: 0.4786818	total: 2m 29s	remaining: 9m 3s
# 216:	learn: 0.4786812	total: 2m 30s	remaining: 9m 2s
# 217:	learn: 0.4786804	total: 2m 30s	remaining: 9m 1s
# 218:	learn: 0.4786796	total: 2m 31s	remaining: 9m
# 219:	learn: 0.4786784	total: 2m 32s	remaining: 9m
# 220:	learn: 0.4786780	total: 2m 32s	remaining: 8m 59s
# 221:	learn: 0.4786777	total: 2m 33s	remaining: 8m 58s
# 222:	learn: 0.4786767	total: 2m 34s	remaining: 8m 57s
# 223:	learn: 0.4786765	total: 2m 34s	remaining: 8m 56s
# 224:	learn: 0.4786756	total: 2m 35s	remaining: 8m 55s
# 225:	learn: 0.4786747	total: 2m 36s	remaining: 8m 54s
# 226:	learn: 0.4786737	total: 2m 36s	remaining: 8m 54s
# 227:	learn: 0.4786729	total: 2m 37s	remaining: 8m 53s
# 228:	learn: 0.4786715	total: 2m 38s	remaining: 8m 52s
# 229:	learn: 0.4786711	total: 2m 38s	remaining: 8m 51s
# 230:	learn: 0.4786708	total: 2m 39s	remaining: 8m 50s
# 231:	learn: 0.4786692	total: 2m 40s	remaining: 8m 50s
# 232:	learn: 0.4786685	total: 2m 40s	remaining: 8m 49s
# 233:	learn: 0.4786673	total: 2m 41s	remaining: 8m 48s
# 234:	learn: 0.4786667	total: 2m 42s	remaining: 8m 47s
# 235:	learn: 0.4786660	total: 2m 42s	remaining: 8m 46s
# 236:	learn: 0.4786657	total: 2m 43s	remaining: 8m 45s
# 237:	learn: 0.4786641	total: 2m 44s	remaining: 8m 45s
# 238:	learn: 0.4786629	total: 2m 44s	remaining: 8m 44s
# 239:	learn: 0.4786625	total: 2m 45s	remaining: 8m 43s
# 240:	learn: 0.4786623	total: 2m 45s	remaining: 8m 42s
# 241:	learn: 0.4786615	total: 2m 46s	remaining: 8m 41s
# 242:	learn: 0.4786611	total: 2m 47s	remaining: 8m 40s
# 243:	learn: 0.4786606	total: 2m 47s	remaining: 8m 40s
# 244:	learn: 0.4786599	total: 2m 48s	remaining: 8m 39s
# 245:	learn: 0.4786592	total: 2m 49s	remaining: 8m 38s
# 246:	learn: 0.4786588	total: 2m 49s	remaining: 8m 37s
# 247:	learn: 0.4786579	total: 2m 50s	remaining: 8m 36s
# 248:	learn: 0.4786562	total: 2m 51s	remaining: 8m 36s
# 249:	learn: 0.4786557	total: 2m 51s	remaining: 8m 35s
# 250:	learn: 0.4786553	total: 2m 52s	remaining: 8m 34s
# 251:	learn: 0.4786549	total: 2m 52s	remaining: 8m 33s
# 252:	learn: 0.4786543	total: 2m 53s	remaining: 8m 32s
# 253:	learn: 0.4786534	total: 2m 54s	remaining: 8m 31s
# 254:	learn: 0.4786530	total: 2m 54s	remaining: 8m 30s
# 255:	learn: 0.4786527	total: 2m 55s	remaining: 8m 30s
# 256:	learn: 0.4786519	total: 2m 56s	remaining: 8m 29s
# 257:	learn: 0.4786515	total: 2m 56s	remaining: 8m 28s
# 258:	learn: 0.4786504	total: 2m 57s	remaining: 8m 28s
# 259:	learn: 0.4786500	total: 2m 58s	remaining: 8m 27s
# 260:	learn: 0.4786497	total: 2m 58s	remaining: 8m 26s
# 261:	learn: 0.4786490	total: 2m 59s	remaining: 8m 25s
# 262:	learn: 0.4786488	total: 3m	remaining: 8m 24s
# 263:	learn: 0.4786480	total: 3m	remaining: 8m 23s
# 264:	learn: 0.4786469	total: 3m 1s	remaining: 8m 22s
# 265:	learn: 0.4786461	total: 3m 2s	remaining: 8m 22s
# 266:	learn: 0.4786455	total: 3m 2s	remaining: 8m 21s
# 267:	learn: 0.4786447	total: 3m 3s	remaining: 8m 20s
# 268:	learn: 0.4786440	total: 3m 3s	remaining: 8m 19s
# 269:	learn: 0.4786435	total: 3m 4s	remaining: 8m 19s
# 270:	learn: 0.4786429	total: 3m 5s	remaining: 8m 18s
# 271:	learn: 0.4786421	total: 3m 5s	remaining: 8m 17s
# 272:	learn: 0.4786412	total: 3m 6s	remaining: 8m 17s
# 273:	learn: 0.4786407	total: 3m 7s	remaining: 8m 16s
# 274:	learn: 0.4786391	total: 3m 8s	remaining: 8m 15s
# 275:	learn: 0.4786380	total: 3m 8s	remaining: 8m 15s
# 276:	learn: 0.4786375	total: 3m 9s	remaining: 8m 14s
# 277:	learn: 0.4786371	total: 3m 10s	remaining: 8m 13s
# 278:	learn: 0.4786364	total: 3m 10s	remaining: 8m 12s
# 279:	learn: 0.4786355	total: 3m 11s	remaining: 8m 12s
# 280:	learn: 0.4786351	total: 3m 12s	remaining: 8m 11s
# 281:	learn: 0.4786348	total: 3m 12s	remaining: 8m 10s
# 282:	learn: 0.4786344	total: 3m 13s	remaining: 8m 9s
# 283:	learn: 0.4786341	total: 3m 13s	remaining: 8m 9s
# 284:	learn: 0.4786338	total: 3m 14s	remaining: 8m 8s
# 285:	learn: 0.4786328	total: 3m 15s	remaining: 8m 7s
# 286:	learn: 0.4786325	total: 3m 15s	remaining: 8m 6s
# 287:	learn: 0.4786320	total: 3m 16s	remaining: 8m 5s
# 288:	learn: 0.4786314	total: 3m 17s	remaining: 8m 5s
# 289:	learn: 0.4786302	total: 3m 17s	remaining: 8m 4s
# 290:	learn: 0.4786295	total: 3m 18s	remaining: 8m 3s
# 291:	learn: 0.4786290	total: 3m 19s	remaining: 8m 3s
# 292:	learn: 0.4786282	total: 3m 19s	remaining: 8m 2s
# 293:	learn: 0.4786276	total: 3m 20s	remaining: 8m 1s
# 294:	learn: 0.4786273	total: 3m 21s	remaining: 8m
# 295:	learn: 0.4786268	total: 3m 21s	remaining: 8m
# 296:	learn: 0.4786267	total: 3m 22s	remaining: 7m 59s
# 297:	learn: 0.4786264	total: 3m 23s	remaining: 7m 58s
# 298:	learn: 0.4786259	total: 3m 23s	remaining: 7m 57s
# 299:	learn: 0.4786255	total: 3m 24s	remaining: 7m 56s
# 300:	learn: 0.4786250	total: 3m 25s	remaining: 7m 56s
# 301:	learn: 0.4786246	total: 3m 25s	remaining: 7m 55s
# 302:	learn: 0.4786241	total: 3m 26s	remaining: 7m 54s
# 303:	learn: 0.4786238	total: 3m 27s	remaining: 7m 54s
# 304:	learn: 0.4786235	total: 3m 27s	remaining: 7m 53s
# 305:	learn: 0.4786231	total: 3m 28s	remaining: 7m 52s
# 306:	learn: 0.4786229	total: 3m 28s	remaining: 7m 51s
# 307:	learn: 0.4786226	total: 3m 29s	remaining: 7m 50s
# 308:	learn: 0.4786222	total: 3m 30s	remaining: 7m 49s
# 309:	learn: 0.4786217	total: 3m 30s	remaining: 7m 49s
# 310:	learn: 0.4786208	total: 3m 31s	remaining: 7m 48s
# 311:	learn: 0.4786197	total: 3m 32s	remaining: 7m 47s
# 312:	learn: 0.4786189	total: 3m 32s	remaining: 7m 47s
# 313:	learn: 0.4786186	total: 3m 33s	remaining: 7m 46s
# 314:	learn: 0.4786181	total: 3m 34s	remaining: 7m 45s
# 315:	learn: 0.4786177	total: 3m 34s	remaining: 7m 45s
# 316:	learn: 0.4786173	total: 3m 35s	remaining: 7m 44s
# 317:	learn: 0.4786167	total: 3m 36s	remaining: 7m 43s
# 318:	learn: 0.4786162	total: 3m 36s	remaining: 7m 42s
# 319:	learn: 0.4786158	total: 3m 37s	remaining: 7m 42s
# 320:	learn: 0.4786154	total: 3m 38s	remaining: 7m 41s
# 321:	learn: 0.4786147	total: 3m 38s	remaining: 7m 40s
# 322:	learn: 0.4786142	total: 3m 39s	remaining: 7m 39s
# 323:	learn: 0.4786137	total: 3m 40s	remaining: 7m 39s
# 324:	learn: 0.4786132	total: 3m 40s	remaining: 7m 38s
# 325:	learn: 0.4786129	total: 3m 41s	remaining: 7m 37s
# 326:	learn: 0.4786125	total: 3m 42s	remaining: 7m 37s
# 327:	learn: 0.4786122	total: 3m 42s	remaining: 7m 36s
# 328:	learn: 0.4786117	total: 3m 43s	remaining: 7m 35s
# 329:	learn: 0.4786112	total: 3m 44s	remaining: 7m 34s
# 330:	learn: 0.4786108	total: 3m 44s	remaining: 7m 34s
# 331:	learn: 0.4786102	total: 3m 45s	remaining: 7m 33s
# 332:	learn: 0.4786093	total: 3m 46s	remaining: 7m 32s
# 333:	learn: 0.4786088	total: 3m 46s	remaining: 7m 32s
# 334:	learn: 0.4786086	total: 3m 47s	remaining: 7m 31s
# 335:	learn: 0.4786082	total: 3m 48s	remaining: 7m 30s
# 336:	learn: 0.4786080	total: 3m 48s	remaining: 7m 29s
# 337:	learn: 0.4786077	total: 3m 49s	remaining: 7m 29s
# 338:	learn: 0.4786073	total: 3m 49s	remaining: 7m 28s
# 339:	learn: 0.4786071	total: 3m 50s	remaining: 7m 27s
# 340:	learn: 0.4786066	total: 3m 51s	remaining: 7m 26s
# 341:	learn: 0.4786063	total: 3m 51s	remaining: 7m 26s
# 342:	learn: 0.4786058	total: 3m 52s	remaining: 7m 25s
# 343:	learn: 0.4786050	total: 3m 53s	remaining: 7m 24s
# 344:	learn: 0.4786048	total: 3m 53s	remaining: 7m 24s
# 345:	learn: 0.4786043	total: 3m 54s	remaining: 7m 23s
# 346:	learn: 0.4786039	total: 3m 55s	remaining: 7m 22s
# 347:	learn: 0.4786036	total: 3m 55s	remaining: 7m 21s
# 348:	learn: 0.4786032	total: 3m 56s	remaining: 7m 21s
# 349:	learn: 0.4786026	total: 3m 57s	remaining: 7m 20s
# 350:	learn: 0.4786024	total: 3m 57s	remaining: 7m 19s
# 351:	learn: 0.4786019	total: 3m 58s	remaining: 7m 19s
# 352:	learn: 0.4786015	total: 3m 59s	remaining: 7m 18s
# 353:	learn: 0.4786013	total: 3m 59s	remaining: 7m 17s
# 354:	learn: 0.4786006	total: 4m	remaining: 7m 16s
# 355:	learn: 0.4786003	total: 4m 1s	remaining: 7m 16s
# 356:	learn: 0.4786000	total: 4m 1s	remaining: 7m 15s
# 357:	learn: 0.4785995	total: 4m 2s	remaining: 7m 14s
# 358:	learn: 0.4785992	total: 4m 3s	remaining: 7m 14s
# 359:	learn: 0.4785989	total: 4m 3s	remaining: 7m 13s
# 360:	learn: 0.4785980	total: 4m 4s	remaining: 7m 12s
# 361:	learn: 0.4785978	total: 4m 5s	remaining: 7m 12s
# 362:	learn: 0.4785976	total: 4m 5s	remaining: 7m 11s
# 363:	learn: 0.4785973	total: 4m 6s	remaining: 7m 10s
# 364:	learn: 0.4785965	total: 4m 7s	remaining: 7m 10s
# 365:	learn: 0.4785962	total: 4m 7s	remaining: 7m 9s
# 366:	learn: 0.4785957	total: 4m 8s	remaining: 7m 8s
# 367:	learn: 0.4785955	total: 4m 9s	remaining: 7m 8s
# 368:	learn: 0.4785952	total: 4m 9s	remaining: 7m 7s
# 369:	learn: 0.4785950	total: 4m 10s	remaining: 7m 6s
# 370:	learn: 0.4785947	total: 4m 11s	remaining: 7m 5s
# 371:	learn: 0.4785944	total: 4m 11s	remaining: 7m 5s
# 372:	learn: 0.4785941	total: 4m 12s	remaining: 7m 4s
# 373:	learn: 0.4785938	total: 4m 13s	remaining: 7m 3s
# 374:	learn: 0.4785936	total: 4m 13s	remaining: 7m 3s
# 375:	learn: 0.4785931	total: 4m 14s	remaining: 7m 2s
# 376:	learn: 0.4785926	total: 4m 15s	remaining: 7m 1s
# 377:	learn: 0.4785923	total: 4m 15s	remaining: 7m 1s
# 378:	learn: 0.4785919	total: 4m 16s	remaining: 7m
# 379:	learn: 0.4785915	total: 4m 17s	remaining: 6m 59s
# 380:	learn: 0.4785913	total: 4m 17s	remaining: 6m 58s
# 381:	learn: 0.4785911	total: 4m 18s	remaining: 6m 58s
# 382:	learn: 0.4785908	total: 4m 19s	remaining: 6m 57s
# 383:	learn: 0.4785903	total: 4m 19s	remaining: 6m 56s
# 384:	learn: 0.4785900	total: 4m 20s	remaining: 6m 56s
# 385:	learn: 0.4785898	total: 4m 21s	remaining: 6m 55s
# 386:	learn: 0.4785895	total: 4m 21s	remaining: 6m 54s
# 387:	learn: 0.4785893	total: 4m 22s	remaining: 6m 53s
# 388:	learn: 0.4785890	total: 4m 23s	remaining: 6m 53s
# 389:	learn: 0.4785888	total: 4m 23s	remaining: 6m 52s
# 390:	learn: 0.4785886	total: 4m 24s	remaining: 6m 51s
# 391:	learn: 0.4785883	total: 4m 25s	remaining: 6m 51s
# 392:	learn: 0.4785879	total: 4m 25s	remaining: 6m 50s
# 393:	learn: 0.4785875	total: 4m 26s	remaining: 6m 49s
# 394:	learn: 0.4785873	total: 4m 27s	remaining: 6m 49s
# 395:	learn: 0.4785870	total: 4m 27s	remaining: 6m 48s
# 396:	learn: 0.4785867	total: 4m 28s	remaining: 6m 47s
# 397:	learn: 0.4785865	total: 4m 29s	remaining: 6m 47s
# 398:	learn: 0.4785861	total: 4m 29s	remaining: 6m 46s
# 399:	learn: 0.4785859	total: 4m 30s	remaining: 6m 45s
# 400:	learn: 0.4785854	total: 4m 31s	remaining: 6m 45s
# 401:	learn: 0.4785852	total: 4m 31s	remaining: 6m 44s
# 402:	learn: 0.4785849	total: 4m 32s	remaining: 6m 43s
# 403:	learn: 0.4785845	total: 4m 33s	remaining: 6m 42s
# 404:	learn: 0.4785843	total: 4m 33s	remaining: 6m 42s
# 405:	learn: 0.4785841	total: 4m 34s	remaining: 6m 41s
# 406:	learn: 0.4785839	total: 4m 35s	remaining: 6m 40s
# 407:	learn: 0.4785833	total: 4m 35s	remaining: 6m 40s
# 408:	learn: 0.4785830	total: 4m 36s	remaining: 6m 39s
# 409:	learn: 0.4785827	total: 4m 37s	remaining: 6m 38s
# 410:	learn: 0.4785823	total: 4m 37s	remaining: 6m 38s
# 411:	learn: 0.4785816	total: 4m 38s	remaining: 6m 37s
# 412:	learn: 0.4785812	total: 4m 39s	remaining: 6m 36s
# 413:	learn: 0.4785806	total: 4m 39s	remaining: 6m 36s
# 414:	learn: 0.4785804	total: 4m 40s	remaining: 6m 35s
# 415:	learn: 0.4785800	total: 4m 41s	remaining: 6m 34s
# 416:	learn: 0.4785798	total: 4m 41s	remaining: 6m 34s
# 417:	learn: 0.4785795	total: 4m 42s	remaining: 6m 33s
# 418:	learn: 0.4785794	total: 4m 43s	remaining: 6m 32s
# 419:	learn: 0.4785791	total: 4m 43s	remaining: 6m 32s
# 420:	learn: 0.4785788	total: 4m 44s	remaining: 6m 31s
# 421:	learn: 0.4785783	total: 4m 45s	remaining: 6m 30s
# 422:	learn: 0.4785781	total: 4m 45s	remaining: 6m 29s
# 423:	learn: 0.4785777	total: 4m 46s	remaining: 6m 29s
# 424:	learn: 0.4785776	total: 4m 47s	remaining: 6m 28s
# 425:	learn: 0.4785773	total: 4m 47s	remaining: 6m 27s
# 426:	learn: 0.4785771	total: 4m 48s	remaining: 6m 27s
# 427:	learn: 0.4785767	total: 4m 49s	remaining: 6m 26s
# 428:	learn: 0.4785764	total: 4m 50s	remaining: 6m 25s
# 429:	learn: 0.4785762	total: 4m 50s	remaining: 6m 25s
# 430:	learn: 0.4785759	total: 4m 51s	remaining: 6m 24s
# 431:	learn: 0.4785755	total: 4m 51s	remaining: 6m 23s
# 432:	learn: 0.4785752	total: 4m 52s	remaining: 6m 23s
# 433:	learn: 0.4785750	total: 4m 53s	remaining: 6m 22s
# 434:	learn: 0.4785746	total: 4m 53s	remaining: 6m 21s
# 435:	learn: 0.4785744	total: 4m 54s	remaining: 6m 21s
# 436:	learn: 0.4785739	total: 4m 55s	remaining: 6m 20s
# 437:	learn: 0.4785735	total: 4m 55s	remaining: 6m 19s
# 438:	learn: 0.4785733	total: 4m 56s	remaining: 6m 18s
# 439:	learn: 0.4785731	total: 4m 57s	remaining: 6m 18s
# 440:	learn: 0.4785728	total: 4m 57s	remaining: 6m 17s
# 441:	learn: 0.4785723	total: 4m 58s	remaining: 6m 17s
# 442:	learn: 0.4785722	total: 4m 59s	remaining: 6m 16s
# 443:	learn: 0.4785719	total: 4m 59s	remaining: 6m 15s
# 444:	learn: 0.4785717	total: 5m	remaining: 6m 14s
# 445:	learn: 0.4785713	total: 5m 1s	remaining: 6m 14s
# 446:	learn: 0.4785710	total: 5m 1s	remaining: 6m 13s
# 447:	learn: 0.4785707	total: 5m 2s	remaining: 6m 12s
# 448:	learn: 0.4785705	total: 5m 3s	remaining: 6m 12s
# 449:	learn: 0.4785702	total: 5m 3s	remaining: 6m 11s
# 450:	learn: 0.4785700	total: 5m 4s	remaining: 6m 10s
# 451:	learn: 0.4785696	total: 5m 5s	remaining: 6m 10s
# 452:	learn: 0.4785694	total: 5m 6s	remaining: 6m 9s
# 453:	learn: 0.4785689	total: 5m 6s	remaining: 6m 8s
# 454:	learn: 0.4785686	total: 5m 7s	remaining: 6m 8s
# 455:	learn: 0.4785683	total: 5m 8s	remaining: 6m 7s
# 456:	learn: 0.4785680	total: 5m 8s	remaining: 6m 6s
# 457:	learn: 0.4785679	total: 5m 9s	remaining: 6m 6s
# 458:	learn: 0.4785675	total: 5m 10s	remaining: 6m 5s
# 459:	learn: 0.4785673	total: 5m 10s	remaining: 6m 4s
# 460:	learn: 0.4785670	total: 5m 11s	remaining: 6m 4s
# 461:	learn: 0.4785667	total: 5m 12s	remaining: 6m 3s
# 462:	learn: 0.4785664	total: 5m 12s	remaining: 6m 2s
# 463:	learn: 0.4785661	total: 5m 13s	remaining: 6m 1s
# 464:	learn: 0.4785659	total: 5m 14s	remaining: 6m 1s
# 465:	learn: 0.4785656	total: 5m 14s	remaining: 6m
# 466:	learn: 0.4785653	total: 5m 15s	remaining: 5m 59s
# 467:	learn: 0.4785650	total: 5m 16s	remaining: 5m 59s
# 468:	learn: 0.4785647	total: 5m 16s	remaining: 5m 58s
# 469:	learn: 0.4785644	total: 5m 17s	remaining: 5m 57s
# 470:	learn: 0.4785641	total: 5m 18s	remaining: 5m 57s
# 471:	learn: 0.4785638	total: 5m 18s	remaining: 5m 56s
# 472:	learn: 0.4785635	total: 5m 19s	remaining: 5m 55s
# 473:	learn: 0.4785633	total: 5m 20s	remaining: 5m 55s
# 474:	learn: 0.4785628	total: 5m 20s	remaining: 5m 54s
# 475:	learn: 0.4785625	total: 5m 21s	remaining: 5m 53s
# 476:	learn: 0.4785622	total: 5m 22s	remaining: 5m 53s
# 477:	learn: 0.4785619	total: 5m 22s	remaining: 5m 52s
# 478:	learn: 0.4785616	total: 5m 23s	remaining: 5m 51s
# 479:	learn: 0.4785614	total: 5m 24s	remaining: 5m 51s
# 480:	learn: 0.4785611	total: 5m 24s	remaining: 5m 50s
# 481:	learn: 0.4785609	total: 5m 25s	remaining: 5m 49s
# 482:	learn: 0.4785605	total: 5m 26s	remaining: 5m 48s
# 483:	learn: 0.4785603	total: 5m 26s	remaining: 5m 48s
# 484:	learn: 0.4785601	total: 5m 27s	remaining: 5m 47s
# 485:	learn: 0.4785599	total: 5m 28s	remaining: 5m 46s
# 486:	learn: 0.4785597	total: 5m 28s	remaining: 5m 46s
# 487:	learn: 0.4785595	total: 5m 29s	remaining: 5m 45s
# 488:	learn: 0.4785592	total: 5m 30s	remaining: 5m 44s
# 489:	learn: 0.4785589	total: 5m 30s	remaining: 5m 44s
# 490:	learn: 0.4785587	total: 5m 31s	remaining: 5m 43s
# 491:	learn: 0.4785584	total: 5m 32s	remaining: 5m 42s
# 492:	learn: 0.4785580	total: 5m 32s	remaining: 5m 42s
# 493:	learn: 0.4785578	total: 5m 33s	remaining: 5m 41s
# 494:	learn: 0.4785576	total: 5m 34s	remaining: 5m 40s
# 495:	learn: 0.4785572	total: 5m 34s	remaining: 5m 40s
# 496:	learn: 0.4785570	total: 5m 35s	remaining: 5m 39s
# 497:	learn: 0.4785567	total: 5m 36s	remaining: 5m 39s
# 498:	learn: 0.4785564	total: 5m 37s	remaining: 5m 38s
# 499:	learn: 0.4785562	total: 5m 37s	remaining: 5m 37s
# 500:	learn: 0.4785560	total: 5m 38s	remaining: 5m 37s
# 501:	learn: 0.4785557	total: 5m 39s	remaining: 5m 36s
# 502:	learn: 0.4785555	total: 5m 39s	remaining: 5m 35s
# 503:	learn: 0.4785552	total: 5m 40s	remaining: 5m 35s
# 504:	learn: 0.4785549	total: 5m 41s	remaining: 5m 34s
# 505:	learn: 0.4785546	total: 5m 41s	remaining: 5m 33s
# 506:	learn: 0.4785544	total: 5m 42s	remaining: 5m 33s
# 507:	learn: 0.4785543	total: 5m 43s	remaining: 5m 32s
# 508:	learn: 0.4785540	total: 5m 43s	remaining: 5m 31s
# 509:	learn: 0.4785537	total: 5m 44s	remaining: 5m 30s
# 510:	learn: 0.4785536	total: 5m 45s	remaining: 5m 30s
# 511:	learn: 0.4785531	total: 5m 45s	remaining: 5m 29s
# 512:	learn: 0.4785529	total: 5m 46s	remaining: 5m 28s
# 513:	learn: 0.4785527	total: 5m 47s	remaining: 5m 28s
# 514:	learn: 0.4785525	total: 5m 47s	remaining: 5m 27s
# 515:	learn: 0.4785522	total: 5m 48s	remaining: 5m 27s
# 516:	learn: 0.4785520	total: 5m 49s	remaining: 5m 26s
# 517:	learn: 0.4785518	total: 5m 49s	remaining: 5m 25s
# 518:	learn: 0.4785516	total: 5m 50s	remaining: 5m 24s
# 519:	learn: 0.4785514	total: 5m 51s	remaining: 5m 24s
# 520:	learn: 0.4785511	total: 5m 51s	remaining: 5m 23s
# 521:	learn: 0.4785509	total: 5m 52s	remaining: 5m 22s
# 522:	learn: 0.4785507	total: 5m 53s	remaining: 5m 22s
# 523:	learn: 0.4785505	total: 5m 53s	remaining: 5m 21s
# 524:	learn: 0.4785502	total: 5m 54s	remaining: 5m 20s
# 525:	learn: 0.4785500	total: 5m 55s	remaining: 5m 20s
# 526:	learn: 0.4785498	total: 5m 56s	remaining: 5m 19s
# 527:	learn: 0.4785496	total: 5m 56s	remaining: 5m 18s
# 528:	learn: 0.4785493	total: 5m 57s	remaining: 5m 18s
# 529:	learn: 0.4785490	total: 5m 58s	remaining: 5m 17s
# 530:	learn: 0.4785489	total: 5m 58s	remaining: 5m 16s
# 531:	learn: 0.4785487	total: 5m 59s	remaining: 5m 16s
# 532:	learn: 0.4785485	total: 6m	remaining: 5m 15s
# 533:	learn: 0.4785482	total: 6m	remaining: 5m 14s
# 534:	learn: 0.4785477	total: 6m 1s	remaining: 5m 14s
# 535:	learn: 0.4785475	total: 6m 2s	remaining: 5m 13s
# 536:	learn: 0.4785471	total: 6m 2s	remaining: 5m 12s
# 537:	learn: 0.4785470	total: 6m 3s	remaining: 5m 12s
# 538:	learn: 0.4785468	total: 6m 4s	remaining: 5m 11s
# 539:	learn: 0.4785465	total: 6m 4s	remaining: 5m 10s
# 540:	learn: 0.4785463	total: 6m 5s	remaining: 5m 10s
# 541:	learn: 0.4785461	total: 6m 6s	remaining: 5m 9s
# 542:	learn: 0.4785459	total: 6m 7s	remaining: 5m 8s
# 543:	learn: 0.4785457	total: 6m 7s	remaining: 5m 8s
# 544:	learn: 0.4785455	total: 6m 8s	remaining: 5m 7s
# 545:	learn: 0.4785452	total: 6m 9s	remaining: 5m 7s
# 546:	learn: 0.4785450	total: 6m 9s	remaining: 5m 6s
# 547:	learn: 0.4785447	total: 6m 10s	remaining: 5m 5s
# 548:	learn: 0.4785444	total: 6m 11s	remaining: 5m 5s
# 549:	learn: 0.4785441	total: 6m 12s	remaining: 5m 4s
# 550:	learn: 0.4785440	total: 6m 12s	remaining: 5m 3s
# 551:	learn: 0.4785437	total: 6m 13s	remaining: 5m 3s
# 552:	learn: 0.4785434	total: 6m 14s	remaining: 5m 2s
# 553:	learn: 0.4785432	total: 6m 15s	remaining: 5m 1s
# 554:	learn: 0.4785429	total: 6m 15s	remaining: 5m 1s
# 555:	learn: 0.4785427	total: 6m 16s	remaining: 5m
# 556:	learn: 0.4785425	total: 6m 17s	remaining: 4m 59s
# 557:	learn: 0.4785422	total: 6m 17s	remaining: 4m 59s
# 558:	learn: 0.4785420	total: 6m 18s	remaining: 4m 58s
# 559:	learn: 0.4785417	total: 6m 19s	remaining: 4m 57s
# 560:	learn: 0.4785415	total: 6m 19s	remaining: 4m 57s
# 561:	learn: 0.4785413	total: 6m 20s	remaining: 4m 56s
# 562:	learn: 0.4785410	total: 6m 21s	remaining: 4m 55s
# 563:	learn: 0.4785408	total: 6m 21s	remaining: 4m 55s
# 564:	learn: 0.4785405	total: 6m 22s	remaining: 4m 54s
# 565:	learn: 0.4785403	total: 6m 23s	remaining: 4m 53s
# 566:	learn: 0.4785401	total: 6m 24s	remaining: 4m 53s
# 567:	learn: 0.4785399	total: 6m 25s	remaining: 4m 52s
# 568:	learn: 0.4785397	total: 6m 25s	remaining: 4m 52s
# 569:	learn: 0.4785395	total: 6m 26s	remaining: 4m 51s
# 570:	learn: 0.4785393	total: 6m 27s	remaining: 4m 50s
# 571:	learn: 0.4785391	total: 6m 27s	remaining: 4m 50s
# 572:	learn: 0.4785388	total: 6m 28s	remaining: 4m 49s
# 573:	learn: 0.4785386	total: 6m 29s	remaining: 4m 48s
# 574:	learn: 0.4785383	total: 6m 29s	remaining: 4m 48s
# 575:	learn: 0.4785380	total: 6m 30s	remaining: 4m 47s
# 576:	learn: 0.4785378	total: 6m 31s	remaining: 4m 46s
# 577:	learn: 0.4785376	total: 6m 31s	remaining: 4m 46s
# 578:	learn: 0.4785374	total: 6m 32s	remaining: 4m 45s
# 579:	learn: 0.4785372	total: 6m 33s	remaining: 4m 44s
# 580:	learn: 0.4785370	total: 6m 33s	remaining: 4m 44s
# 581:	learn: 0.4785369	total: 6m 34s	remaining: 4m 43s
# 582:	learn: 0.4785366	total: 6m 35s	remaining: 4m 42s
# 583:	learn: 0.4785363	total: 6m 35s	remaining: 4m 41s
# 584:	learn: 0.4785360	total: 6m 36s	remaining: 4m 41s
# 585:	learn: 0.4785356	total: 6m 37s	remaining: 4m 40s
# 586:	learn: 0.4785354	total: 6m 38s	remaining: 4m 40s
# 587:	learn: 0.4785352	total: 6m 38s	remaining: 4m 39s
# 588:	learn: 0.4785350	total: 6m 39s	remaining: 4m 38s
# 589:	learn: 0.4785348	total: 6m 40s	remaining: 4m 38s
# 590:	learn: 0.4785346	total: 6m 41s	remaining: 4m 37s
# 591:	learn: 0.4785344	total: 6m 41s	remaining: 4m 36s
# 592:	learn: 0.4785341	total: 6m 42s	remaining: 4m 36s
# 593:	learn: 0.4785339	total: 6m 43s	remaining: 4m 35s
# 594:	learn: 0.4785337	total: 6m 43s	remaining: 4m 34s
# 595:	learn: 0.4785335	total: 6m 44s	remaining: 4m 34s
# 596:	learn: 0.4785332	total: 6m 45s	remaining: 4m 33s
# 597:	learn: 0.4785331	total: 6m 45s	remaining: 4m 32s
# 598:	learn: 0.4785328	total: 6m 46s	remaining: 4m 32s
# 599:	learn: 0.4785326	total: 6m 47s	remaining: 4m 31s
# 600:	learn: 0.4785324	total: 6m 47s	remaining: 4m 30s
# 601:	learn: 0.4785321	total: 6m 48s	remaining: 4m 30s
# 602:	learn: 0.4785318	total: 6m 49s	remaining: 4m 29s
# 603:	learn: 0.4785316	total: 6m 50s	remaining: 4m 28s
# 604:	learn: 0.4785314	total: 6m 50s	remaining: 4m 28s
# 605:	learn: 0.4785311	total: 6m 51s	remaining: 4m 27s
# 606:	learn: 0.4785309	total: 6m 52s	remaining: 4m 26s
# 607:	learn: 0.4785307	total: 6m 52s	remaining: 4m 26s
# 608:	learn: 0.4785304	total: 6m 53s	remaining: 4m 25s
# 609:	learn: 0.4785301	total: 6m 54s	remaining: 4m 24s
# 610:	learn: 0.4785300	total: 6m 54s	remaining: 4m 24s
# 611:	learn: 0.4785297	total: 6m 55s	remaining: 4m 23s
# 612:	learn: 0.4785295	total: 6m 56s	remaining: 4m 22s
# 613:	learn: 0.4785293	total: 6m 57s	remaining: 4m 22s
# 614:	learn: 0.4785291	total: 6m 57s	remaining: 4m 21s
# 615:	learn: 0.4785288	total: 6m 58s	remaining: 4m 20s
# 616:	learn: 0.4785287	total: 6m 59s	remaining: 4m 20s
# 617:	learn: 0.4785284	total: 6m 59s	remaining: 4m 19s
# 618:	learn: 0.4785283	total: 7m	remaining: 4m 18s
# 619:	learn: 0.4785282	total: 7m 1s	remaining: 4m 18s
# 620:	learn: 0.4785279	total: 7m 1s	remaining: 4m 17s
# 621:	learn: 0.4785277	total: 7m 2s	remaining: 4m 16s
# 622:	learn: 0.4785276	total: 7m 3s	remaining: 4m 16s
# 623:	learn: 0.4785272	total: 7m 4s	remaining: 4m 15s
# 624:	learn: 0.4785271	total: 7m 4s	remaining: 4m 14s
# 625:	learn: 0.4785268	total: 7m 5s	remaining: 4m 14s
# 626:	learn: 0.4785266	total: 7m 6s	remaining: 4m 13s
# 627:	learn: 0.4785264	total: 7m 6s	remaining: 4m 12s
# 628:	learn: 0.4785261	total: 7m 7s	remaining: 4m 12s
# 629:	learn: 0.4785259	total: 7m 8s	remaining: 4m 11s
# 630:	learn: 0.4785258	total: 7m 8s	remaining: 4m 10s
# 631:	learn: 0.4785256	total: 7m 9s	remaining: 4m 10s
# 632:	learn: 0.4785254	total: 7m 10s	remaining: 4m 9s
# 633:	learn: 0.4785252	total: 7m 10s	remaining: 4m 8s
# 634:	learn: 0.4785250	total: 7m 11s	remaining: 4m 8s
# 635:	learn: 0.4785249	total: 7m 12s	remaining: 4m 7s
# 636:	learn: 0.4785247	total: 7m 12s	remaining: 4m 6s
# 637:	learn: 0.4785244	total: 7m 13s	remaining: 4m 6s
# 638:	learn: 0.4785242	total: 7m 14s	remaining: 4m 5s
# 639:	learn: 0.4785239	total: 7m 15s	remaining: 4m 4s
# 640:	learn: 0.4785236	total: 7m 15s	remaining: 4m 4s
# 641:	learn: 0.4785235	total: 7m 16s	remaining: 4m 3s
# 642:	learn: 0.4785233	total: 7m 17s	remaining: 4m 2s
# 643:	learn: 0.4785231	total: 7m 17s	remaining: 4m 2s
# 644:	learn: 0.4785230	total: 7m 18s	remaining: 4m 1s
# 645:	learn: 0.4785228	total: 7m 19s	remaining: 4m
# 646:	learn: 0.4785225	total: 7m 19s	remaining: 4m
# 647:	learn: 0.4785223	total: 7m 20s	remaining: 3m 59s
# 648:	learn: 0.4785222	total: 7m 21s	remaining: 3m 58s
# 649:	learn: 0.4785220	total: 7m 22s	remaining: 3m 58s
# 650:	learn: 0.4785218	total: 7m 22s	remaining: 3m 57s
# 651:	learn: 0.4785215	total: 7m 23s	remaining: 3m 56s
# 652:	learn: 0.4785214	total: 7m 24s	remaining: 3m 56s
# 653:	learn: 0.4785212	total: 7m 24s	remaining: 3m 55s
# 654:	learn: 0.4785210	total: 7m 25s	remaining: 3m 54s
# 655:	learn: 0.4785208	total: 7m 26s	remaining: 3m 53s
# 656:	learn: 0.4785206	total: 7m 26s	remaining: 3m 53s
# 657:	learn: 0.4785204	total: 7m 27s	remaining: 3m 52s
# 658:	learn: 0.4785202	total: 7m 28s	remaining: 3m 51s
# 659:	learn: 0.4785200	total: 7m 28s	remaining: 3m 51s
# 660:	learn: 0.4785199	total: 7m 29s	remaining: 3m 50s
# 661:	learn: 0.4785196	total: 7m 30s	remaining: 3m 49s
# 662:	learn: 0.4785194	total: 7m 30s	remaining: 3m 49s
# 663:	learn: 0.4785193	total: 7m 31s	remaining: 3m 48s
# 664:	learn: 0.4785190	total: 7m 32s	remaining: 3m 47s
# 665:	learn: 0.4785188	total: 7m 33s	remaining: 3m 47s
# 666:	learn: 0.4785185	total: 7m 33s	remaining: 3m 46s
# 667:	learn: 0.4785183	total: 7m 34s	remaining: 3m 45s
# 668:	learn: 0.4785181	total: 7m 35s	remaining: 3m 45s
# 669:	learn: 0.4785178	total: 7m 36s	remaining: 3m 44s
# 670:	learn: 0.4785176	total: 7m 36s	remaining: 3m 43s
# 671:	learn: 0.4785174	total: 7m 37s	remaining: 3m 43s
# 672:	learn: 0.4785172	total: 7m 38s	remaining: 3m 42s
# 673:	learn: 0.4785170	total: 7m 38s	remaining: 3m 41s
# 674:	learn: 0.4785169	total: 7m 39s	remaining: 3m 41s
# 675:	learn: 0.4785167	total: 7m 40s	remaining: 3m 40s
# 676:	learn: 0.4785165	total: 7m 40s	remaining: 3m 39s
# 677:	learn: 0.4785163	total: 7m 41s	remaining: 3m 39s
# 678:	learn: 0.4785161	total: 7m 42s	remaining: 3m 38s
# 679:	learn: 0.4785159	total: 7m 43s	remaining: 3m 37s
# 680:	learn: 0.4785156	total: 7m 43s	remaining: 3m 37s
# 681:	learn: 0.4785153	total: 7m 44s	remaining: 3m 36s
# 682:	learn: 0.4785151	total: 7m 45s	remaining: 3m 35s
# 683:	learn: 0.4785149	total: 7m 45s	remaining: 3m 35s
# 684:	learn: 0.4785147	total: 7m 46s	remaining: 3m 34s
# 685:	learn: 0.4785144	total: 7m 47s	remaining: 3m 33s
# 686:	learn: 0.4785141	total: 7m 48s	remaining: 3m 33s
# 687:	learn: 0.4785139	total: 7m 48s	remaining: 3m 32s
# 688:	learn: 0.4785137	total: 7m 49s	remaining: 3m 31s
# 689:	learn: 0.4785135	total: 7m 50s	remaining: 3m 31s
# 690:	learn: 0.4785133	total: 7m 50s	remaining: 3m 30s
# 691:	learn: 0.4785130	total: 7m 51s	remaining: 3m 29s
# 692:	learn: 0.4785128	total: 7m 52s	remaining: 3m 29s
# 693:	learn: 0.4785126	total: 7m 52s	remaining: 3m 28s
# 694:	learn: 0.4785125	total: 7m 53s	remaining: 3m 27s
# 695:	learn: 0.4785122	total: 7m 54s	remaining: 3m 27s
# 696:	learn: 0.4785121	total: 7m 55s	remaining: 3m 26s
# 697:	learn: 0.4785118	total: 7m 55s	remaining: 3m 25s
# 698:	learn: 0.4785117	total: 7m 56s	remaining: 3m 25s
# 699:	learn: 0.4785115	total: 7m 57s	remaining: 3m 24s
# 700:	learn: 0.4785113	total: 7m 57s	remaining: 3m 23s
# 701:	learn: 0.4785112	total: 7m 58s	remaining: 3m 23s
# 702:	learn: 0.4785109	total: 7m 59s	remaining: 3m 22s
# 703:	learn: 0.4785108	total: 7m 59s	remaining: 3m 21s
# 704:	learn: 0.4785105	total: 8m	remaining: 3m 21s
# 705:	learn: 0.4785104	total: 8m 1s	remaining: 3m 20s
# 706:	learn: 0.4785102	total: 8m 2s	remaining: 3m 19s
# 707:	learn: 0.4785100	total: 8m 2s	remaining: 3m 19s
# 708:	learn: 0.4785098	total: 8m 3s	remaining: 3m 18s
# 709:	learn: 0.4785097	total: 8m 4s	remaining: 3m 17s
# 710:	learn: 0.4785095	total: 8m 4s	remaining: 3m 17s
# 711:	learn: 0.4785093	total: 8m 5s	remaining: 3m 16s
# 712:	learn: 0.4785091	total: 8m 6s	remaining: 3m 15s
# 713:	learn: 0.4785090	total: 8m 7s	remaining: 3m 15s
# 714:	learn: 0.4785089	total: 8m 7s	remaining: 3m 14s
# 715:	learn: 0.4785087	total: 8m 8s	remaining: 3m 13s
# 716:	learn: 0.4785084	total: 8m 9s	remaining: 3m 13s
# 717:	learn: 0.4785083	total: 8m 9s	remaining: 3m 12s
# 718:	learn: 0.4785082	total: 8m 10s	remaining: 3m 11s
# 719:	learn: 0.4785080	total: 8m 11s	remaining: 3m 11s
# 720:	learn: 0.4785078	total: 8m 11s	remaining: 3m 10s
# 721:	learn: 0.4785076	total: 8m 12s	remaining: 3m 9s
# 722:	learn: 0.4785075	total: 8m 13s	remaining: 3m 8s
# 723:	learn: 0.4785072	total: 8m 14s	remaining: 3m 8s
# 724:	learn: 0.4785069	total: 8m 14s	remaining: 3m 7s
# 725:	learn: 0.4785066	total: 8m 15s	remaining: 3m 7s
# 726:	learn: 0.4785064	total: 8m 16s	remaining: 3m 6s
# 727:	learn: 0.4785062	total: 8m 16s	remaining: 3m 5s
# 728:	learn: 0.4785059	total: 8m 17s	remaining: 3m 5s
# 729:	learn: 0.4785057	total: 8m 18s	remaining: 3m 4s
# 730:	learn: 0.4785055	total: 8m 19s	remaining: 3m 3s
# 731:	learn: 0.4785052	total: 8m 19s	remaining: 3m 3s
# 732:	learn: 0.4785051	total: 8m 20s	remaining: 3m 2s
# 733:	learn: 0.4785049	total: 8m 21s	remaining: 3m 1s
# 734:	learn: 0.4785047	total: 8m 22s	remaining: 3m 1s
# 735:	learn: 0.4785045	total: 8m 22s	remaining: 3m
# 736:	learn: 0.4785043	total: 8m 23s	remaining: 2m 59s
# 737:	learn: 0.4785042	total: 8m 24s	remaining: 2m 58s
# 738:	learn: 0.4785039	total: 8m 24s	remaining: 2m 58s
# 739:	learn: 0.4785037	total: 8m 25s	remaining: 2m 57s
# 740:	learn: 0.4785035	total: 8m 26s	remaining: 2m 56s
# 741:	learn: 0.4785033	total: 8m 26s	remaining: 2m 56s
# 742:	learn: 0.4785032	total: 8m 27s	remaining: 2m 55s
# 743:	learn: 0.4785030	total: 8m 28s	remaining: 2m 54s
# 744:	learn: 0.4785028	total: 8m 29s	remaining: 2m 54s
# 745:	learn: 0.4785026	total: 8m 29s	remaining: 2m 53s
# 746:	learn: 0.4785024	total: 8m 30s	remaining: 2m 52s
# 747:	learn: 0.4785023	total: 8m 31s	remaining: 2m 52s
# 748:	learn: 0.4785021	total: 8m 31s	remaining: 2m 51s
# 749:	learn: 0.4785019	total: 8m 32s	remaining: 2m 50s
# 750:	learn: 0.4785017	total: 8m 33s	remaining: 2m 50s
# 751:	learn: 0.4785015	total: 8m 34s	remaining: 2m 49s
# 752:	learn: 0.4785014	total: 8m 34s	remaining: 2m 48s
# 753:	learn: 0.4785012	total: 8m 35s	remaining: 2m 48s
# 754:	learn: 0.4785010	total: 8m 36s	remaining: 2m 47s
# 755:	learn: 0.4785008	total: 8m 36s	remaining: 2m 46s
# 756:	learn: 0.4785007	total: 8m 37s	remaining: 2m 46s
# 757:	learn: 0.4785005	total: 8m 38s	remaining: 2m 45s
# 758:	learn: 0.4785002	total: 8m 38s	remaining: 2m 44s
# 759:	learn: 0.4785000	total: 8m 39s	remaining: 2m 44s
# 760:	learn: 0.4784998	total: 8m 40s	remaining: 2m 43s
# 761:	learn: 0.4784996	total: 8m 40s	remaining: 2m 42s
# 762:	learn: 0.4784994	total: 8m 41s	remaining: 2m 42s
# 763:	learn: 0.4784992	total: 8m 42s	remaining: 2m 41s
# 764:	learn: 0.4784991	total: 8m 42s	remaining: 2m 40s
# 765:	learn: 0.4784989	total: 8m 43s	remaining: 2m 39s
# 766:	learn: 0.4784987	total: 8m 44s	remaining: 2m 39s
# 767:	learn: 0.4784985	total: 8m 44s	remaining: 2m 38s
# 768:	learn: 0.4784983	total: 8m 45s	remaining: 2m 37s
# 769:	learn: 0.4784981	total: 8m 46s	remaining: 2m 37s
# 770:	learn: 0.4784979	total: 8m 47s	remaining: 2m 36s
# 771:	learn: 0.4784977	total: 8m 47s	remaining: 2m 35s
# 772:	learn: 0.4784975	total: 8m 48s	remaining: 2m 35s
# 773:	learn: 0.4784973	total: 8m 49s	remaining: 2m 34s
# 774:	learn: 0.4784970	total: 8m 49s	remaining: 2m 33s
# 775:	learn: 0.4784969	total: 8m 50s	remaining: 2m 33s
# 776:	learn: 0.4784967	total: 8m 51s	remaining: 2m 32s
# 777:	learn: 0.4784965	total: 8m 51s	remaining: 2m 31s
# 778:	learn: 0.4784964	total: 8m 52s	remaining: 2m 31s
# 779:	learn: 0.4784963	total: 8m 53s	remaining: 2m 30s
# 780:	learn: 0.4784962	total: 8m 53s	remaining: 2m 29s
# 781:	learn: 0.4784959	total: 8m 54s	remaining: 2m 29s
# 782:	learn: 0.4784957	total: 8m 55s	remaining: 2m 28s
# 783:	learn: 0.4784956	total: 8m 55s	remaining: 2m 27s
# 784:	learn: 0.4784954	total: 8m 56s	remaining: 2m 26s
# 785:	learn: 0.4784953	total: 8m 57s	remaining: 2m 26s
# 786:	learn: 0.4784951	total: 8m 57s	remaining: 2m 25s
# 787:	learn: 0.4784950	total: 8m 58s	remaining: 2m 24s
# 788:	learn: 0.4784949	total: 8m 59s	remaining: 2m 24s
# 789:	learn: 0.4784947	total: 8m 59s	remaining: 2m 23s
# 790:	learn: 0.4784945	total: 9m	remaining: 2m 22s
# 791:	learn: 0.4784944	total: 9m 1s	remaining: 2m 22s
# 792:	learn: 0.4784942	total: 9m 1s	remaining: 2m 21s
# 793:	learn: 0.4784940	total: 9m 2s	remaining: 2m 20s
# 794:	learn: 0.4784939	total: 9m 3s	remaining: 2m 20s
# 795:	learn: 0.4784938	total: 9m 4s	remaining: 2m 19s
# 796:	learn: 0.4784936	total: 9m 4s	remaining: 2m 18s
# 797:	learn: 0.4784933	total: 9m 5s	remaining: 2m 18s
# 798:	learn: 0.4784932	total: 9m 6s	remaining: 2m 17s
# 799:	learn: 0.4784931	total: 9m 6s	remaining: 2m 16s
# 800:	learn: 0.4784929	total: 9m 7s	remaining: 2m 16s
# 801:	learn: 0.4784927	total: 9m 8s	remaining: 2m 15s
# 802:	learn: 0.4784925	total: 9m 8s	remaining: 2m 14s
# 803:	learn: 0.4784922	total: 9m 9s	remaining: 2m 14s
# 804:	learn: 0.4784921	total: 9m 10s	remaining: 2m 13s
# 805:	learn: 0.4784920	total: 9m 11s	remaining: 2m 12s
# 806:	learn: 0.4784918	total: 9m 11s	remaining: 2m 11s
# 807:	learn: 0.4784916	total: 9m 12s	remaining: 2m 11s
# 808:	learn: 0.4784914	total: 9m 13s	remaining: 2m 10s
# 809:	learn: 0.4784913	total: 9m 13s	remaining: 2m 9s
# 810:	learn: 0.4784912	total: 9m 14s	remaining: 2m 9s
# 811:	learn: 0.4784911	total: 9m 15s	remaining: 2m 8s
# 812:	learn: 0.4784909	total: 9m 15s	remaining: 2m 7s
# 813:	learn: 0.4784907	total: 9m 16s	remaining: 2m 7s
# 814:	learn: 0.4784904	total: 9m 17s	remaining: 2m 6s
# 815:	learn: 0.4784903	total: 9m 17s	remaining: 2m 5s
# 816:	learn: 0.4784901	total: 9m 18s	remaining: 2m 5s
# 817:	learn: 0.4784900	total: 9m 19s	remaining: 2m 4s
# 818:	learn: 0.4784899	total: 9m 19s	remaining: 2m 3s
# 819:	learn: 0.4784897	total: 9m 20s	remaining: 2m 3s
# 820:	learn: 0.4784895	total: 9m 21s	remaining: 2m 2s
# 821:	learn: 0.4784893	total: 9m 22s	remaining: 2m 1s
# 822:	learn: 0.4784891	total: 9m 22s	remaining: 2m 1s
# 823:	learn: 0.4784888	total: 9m 23s	remaining: 2m
# 824:	learn: 0.4784887	total: 9m 24s	remaining: 1m 59s
# 825:	learn: 0.4784884	total: 9m 25s	remaining: 1m 59s
# 826:	learn: 0.4784883	total: 9m 25s	remaining: 1m 58s
# 827:	learn: 0.4784882	total: 9m 26s	remaining: 1m 57s
# 828:	learn: 0.4784880	total: 9m 27s	remaining: 1m 57s
# 829:	learn: 0.4784878	total: 9m 28s	remaining: 1m 56s
# 830:	learn: 0.4784876	total: 9m 28s	remaining: 1m 55s
# 831:	learn: 0.4784874	total: 9m 29s	remaining: 1m 55s
# 832:	learn: 0.4784873	total: 9m 30s	remaining: 1m 54s
# 833:	learn: 0.4784870	total: 9m 31s	remaining: 1m 53s
# 834:	learn: 0.4784869	total: 9m 31s	remaining: 1m 52s
# 835:	learn: 0.4784867	total: 9m 32s	remaining: 1m 52s
# 836:	learn: 0.4784866	total: 9m 33s	remaining: 1m 51s
# 837:	learn: 0.4784864	total: 9m 33s	remaining: 1m 50s
# 838:	learn: 0.4784861	total: 9m 34s	remaining: 1m 50s
# 839:	learn: 0.4784859	total: 9m 35s	remaining: 1m 49s
# 840:	learn: 0.4784858	total: 9m 35s	remaining: 1m 48s
# 841:	learn: 0.4784857	total: 9m 36s	remaining: 1m 48s
# 842:	learn: 0.4784855	total: 9m 37s	remaining: 1m 47s
# 843:	learn: 0.4784853	total: 9m 37s	remaining: 1m 46s
# 844:	learn: 0.4784851	total: 9m 38s	remaining: 1m 46s
# 845:	learn: 0.4784849	total: 9m 39s	remaining: 1m 45s
# 846:	learn: 0.4784848	total: 9m 40s	remaining: 1m 44s
# 847:	learn: 0.4784846	total: 9m 40s	remaining: 1m 44s
# 848:	learn: 0.4784843	total: 9m 41s	remaining: 1m 43s
# 849:	learn: 0.4784841	total: 9m 42s	remaining: 1m 42s
# 850:	learn: 0.4784840	total: 9m 43s	remaining: 1m 42s
# 851:	learn: 0.4784838	total: 9m 43s	remaining: 1m 41s
# 852:	learn: 0.4784836	total: 9m 44s	remaining: 1m 40s
# 853:	learn: 0.4784834	total: 9m 45s	remaining: 1m 40s
# 854:	learn: 0.4784833	total: 9m 46s	remaining: 1m 39s
# 855:	learn: 0.4784831	total: 9m 46s	remaining: 1m 38s
# 856:	learn: 0.4784829	total: 9m 47s	remaining: 1m 38s
# 857:	learn: 0.4784827	total: 9m 48s	remaining: 1m 37s
# 858:	learn: 0.4784825	total: 9m 49s	remaining: 1m 36s
# 859:	learn: 0.4784823	total: 9m 49s	remaining: 1m 36s
# 860:	learn: 0.4784821	total: 9m 50s	remaining: 1m 35s
# 861:	learn: 0.4784819	total: 9m 51s	remaining: 1m 34s
# 862:	learn: 0.4784818	total: 9m 52s	remaining: 1m 34s
# 863:	learn: 0.4784816	total: 9m 52s	remaining: 1m 33s
# 864:	learn: 0.4784815	total: 9m 53s	remaining: 1m 32s
# 865:	learn: 0.4784814	total: 9m 54s	remaining: 1m 31s
# 866:	learn: 0.4784812	total: 9m 55s	remaining: 1m 31s
# 867:	learn: 0.4784810	total: 9m 55s	remaining: 1m 30s
# 868:	learn: 0.4784808	total: 9m 56s	remaining: 1m 29s
# 869:	learn: 0.4784806	total: 9m 57s	remaining: 1m 29s
# 870:	learn: 0.4784804	total: 9m 58s	remaining: 1m 28s
# 871:	learn: 0.4784803	total: 9m 59s	remaining: 1m 27s
# 872:	learn: 0.4784801	total: 9m 59s	remaining: 1m 27s
# 873:	learn: 0.4784799	total: 10m	remaining: 1m 26s
# 874:	learn: 0.4784798	total: 10m 1s	remaining: 1m 25s
# 875:	learn: 0.4784796	total: 10m 2s	remaining: 1m 25s
# 876:	learn: 0.4784794	total: 10m 2s	remaining: 1m 24s
# 877:	learn: 0.4784793	total: 10m 3s	remaining: 1m 23s
# 878:	learn: 0.4784791	total: 10m 4s	remaining: 1m 23s
# 879:	learn: 0.4784789	total: 10m 5s	remaining: 1m 22s
# 880:	learn: 0.4784788	total: 10m 5s	remaining: 1m 21s
# 881:	learn: 0.4784786	total: 10m 6s	remaining: 1m 21s
# 882:	learn: 0.4784785	total: 10m 7s	remaining: 1m 20s
# 883:	learn: 0.4784783	total: 10m 8s	remaining: 1m 19s
# 884:	learn: 0.4784781	total: 10m 8s	remaining: 1m 19s
# 885:	learn: 0.4784780	total: 10m 9s	remaining: 1m 18s
# 886:	learn: 0.4784779	total: 10m 10s	remaining: 1m 17s
# 887:	learn: 0.4784777	total: 10m 10s	remaining: 1m 17s
# 888:	learn: 0.4784776	total: 10m 11s	remaining: 1m 16s
# 889:	learn: 0.4784774	total: 10m 12s	remaining: 1m 15s
# 890:	learn: 0.4784772	total: 10m 13s	remaining: 1m 15s
# 891:	learn: 0.4784770	total: 10m 13s	remaining: 1m 14s
# 892:	learn: 0.4784769	total: 10m 14s	remaining: 1m 13s
# 893:	learn: 0.4784767	total: 10m 15s	remaining: 1m 12s
# 894:	learn: 0.4784766	total: 10m 16s	remaining: 1m 12s
# 895:	learn: 0.4784764	total: 10m 17s	remaining: 1m 11s
# 896:	learn: 0.4784763	total: 10m 17s	remaining: 1m 10s
# 897:	learn: 0.4784761	total: 10m 18s	remaining: 1m 10s
# 898:	learn: 0.4784759	total: 10m 19s	remaining: 1m 9s
# 899:	learn: 0.4784758	total: 10m 20s	remaining: 1m 8s
# 900:	learn: 0.4784757	total: 10m 20s	remaining: 1m 8s
# 901:	learn: 0.4784755	total: 10m 21s	remaining: 1m 7s
# 902:	learn: 0.4784754	total: 10m 22s	remaining: 1m 6s
# 903:	learn: 0.4784752	total: 10m 23s	remaining: 1m 6s
# 904:	learn: 0.4784751	total: 10m 24s	remaining: 1m 5s
# 905:	learn: 0.4784750	total: 10m 25s	remaining: 1m 4s
# 906:	learn: 0.4784748	total: 10m 26s	remaining: 1m 4s
# 907:	learn: 0.4784747	total: 10m 27s	remaining: 1m 3s
# 908:	learn: 0.4784745	total: 10m 27s	remaining: 1m 2s
# 909:	learn: 0.4784743	total: 10m 28s	remaining: 1m 2s
# 910:	learn: 0.4784741	total: 10m 29s	remaining: 1m 1s
# 911:	learn: 0.4784739	total: 10m 30s	remaining: 1m
# 912:	learn: 0.4784737	total: 10m 31s	remaining: 1m
# 913:	learn: 0.4784736	total: 10m 31s	remaining: 59.5s
# 914:	learn: 0.4784733	total: 10m 32s	remaining: 58.8s
# 915:	learn: 0.4784733	total: 10m 33s	remaining: 58.1s
# 916:	learn: 0.4784731	total: 10m 34s	remaining: 57.4s
# 917:	learn: 0.4784729	total: 10m 35s	remaining: 56.7s
# 918:	learn: 0.4784728	total: 10m 35s	remaining: 56.1s
# 919:	learn: 0.4784726	total: 10m 36s	remaining: 55.4s
# 920:	learn: 0.4784725	total: 10m 37s	remaining: 54.7s
# 921:	learn: 0.4784723	total: 10m 38s	remaining: 54s
# 922:	learn: 0.4784721	total: 10m 39s	remaining: 53.3s
# 923:	learn: 0.4784719	total: 10m 39s	remaining: 52.6s
# 924:	learn: 0.4784718	total: 10m 40s	remaining: 51.9s
# 925:	learn: 0.4784717	total: 10m 41s	remaining: 51.3s
# 926:	learn: 0.4784715	total: 10m 42s	remaining: 50.6s
# 927:	learn: 0.4784714	total: 10m 42s	remaining: 49.9s
# 928:	learn: 0.4784711	total: 10m 43s	remaining: 49.2s
# 929:	learn: 0.4784710	total: 10m 44s	remaining: 48.5s
# 930:	learn: 0.4784708	total: 10m 45s	remaining: 47.8s
# 931:	learn: 0.4784706	total: 10m 45s	remaining: 47.1s
# 932:	learn: 0.4784705	total: 10m 46s	remaining: 46.4s
# 933:	learn: 0.4784703	total: 10m 47s	remaining: 45.8s
# 934:	learn: 0.4784702	total: 10m 48s	remaining: 45.1s
# 935:	learn: 0.4784700	total: 10m 49s	remaining: 44.4s
# 936:	learn: 0.4784698	total: 10m 49s	remaining: 43.7s
# 937:	learn: 0.4784696	total: 10m 50s	remaining: 43s
# 938:	learn: 0.4784695	total: 10m 51s	remaining: 42.3s
# 939:	learn: 0.4784693	total: 10m 52s	remaining: 41.6s
# 940:	learn: 0.4784691	total: 10m 53s	remaining: 40.9s
# 941:	learn: 0.4784690	total: 10m 53s	remaining: 40.3s
# 942:	learn: 0.4784689	total: 10m 54s	remaining: 39.6s
# 943:	learn: 0.4784687	total: 10m 55s	remaining: 38.9s
# 944:	learn: 0.4784685	total: 10m 56s	remaining: 38.2s
# 945:	learn: 0.4784683	total: 10m 56s	remaining: 37.5s
# 946:	learn: 0.4784682	total: 10m 57s	remaining: 36.8s
# 947:	learn: 0.4784681	total: 10m 58s	remaining: 36.1s
# 948:	learn: 0.4784678	total: 10m 59s	remaining: 35.5s
# 949:	learn: 0.4784676	total: 11m	remaining: 34.8s
# 950:	learn: 0.4784674	total: 11m 1s	remaining: 34.1s
# 951:	learn: 0.4784672	total: 11m 2s	remaining: 33.4s
# 952:	learn: 0.4784671	total: 11m 3s	remaining: 32.7s
# 953:	learn: 0.4784670	total: 11m 3s	remaining: 32s
# 954:	learn: 0.4784669	total: 11m 4s	remaining: 31.3s
# 955:	learn: 0.4784667	total: 11m 5s	remaining: 30.6s
# 956:	learn: 0.4784665	total: 11m 6s	remaining: 29.9s
# 957:	learn: 0.4784663	total: 11m 6s	remaining: 29.2s
# 958:	learn: 0.4784662	total: 11m 7s	remaining: 28.5s
# 959:	learn: 0.4784660	total: 11m 8s	remaining: 27.8s
# 960:	learn: 0.4784658	total: 11m 8s	remaining: 27.1s
# 961:	learn: 0.4784656	total: 11m 9s	remaining: 26.4s
# 962:	learn: 0.4784655	total: 11m 10s	remaining: 25.8s
# 963:	learn: 0.4784653	total: 11m 11s	remaining: 25.1s
# 964:	learn: 0.4784650	total: 11m 11s	remaining: 24.4s
# 965:	learn: 0.4784649	total: 11m 12s	remaining: 23.7s
# 966:	learn: 0.4784648	total: 11m 13s	remaining: 23s
# 967:	learn: 0.4784646	total: 11m 14s	remaining: 22.3s
# 968:	learn: 0.4784644	total: 11m 14s	remaining: 21.6s
# 969:	learn: 0.4784642	total: 11m 15s	remaining: 20.9s
# 970:	learn: 0.4784641	total: 11m 16s	remaining: 20.2s
# 971:	learn: 0.4784639	total: 11m 17s	remaining: 19.5s
# 972:	learn: 0.4784637	total: 11m 18s	remaining: 18.8s
# 973:	learn: 0.4784636	total: 11m 18s	remaining: 18.1s
# 974:	learn: 0.4784634	total: 11m 19s	remaining: 17.4s
# 975:	learn: 0.4784633	total: 11m 20s	remaining: 16.7s
# 976:	learn: 0.4784630	total: 11m 21s	remaining: 16s
# 977:	learn: 0.4784629	total: 11m 21s	remaining: 15.3s
# 978:	learn: 0.4784627	total: 11m 22s	remaining: 14.6s
# 979:	learn: 0.4784625	total: 11m 23s	remaining: 13.9s
# 980:	learn: 0.4784623	total: 11m 23s	remaining: 13.2s
# 981:	learn: 0.4784621	total: 11m 24s	remaining: 12.6s
# 982:	learn: 0.4784619	total: 11m 25s	remaining: 11.9s
# 983:	learn: 0.4784617	total: 11m 26s	remaining: 11.2s
# 984:	learn: 0.4784616	total: 11m 26s	remaining: 10.5s
# 985:	learn: 0.4784615	total: 11m 27s	remaining: 9.76s
# 986:	learn: 0.4784613	total: 11m 28s	remaining: 9.06s
# 987:	learn: 0.4784612	total: 11m 28s	remaining: 8.37s
# 988:	learn: 0.4784610	total: 11m 29s	remaining: 7.67s
# 989:	learn: 0.4784608	total: 11m 30s	remaining: 6.97s
# 990:	learn: 0.4784607	total: 11m 30s	remaining: 6.28s
# 991:	learn: 0.4784605	total: 11m 31s	remaining: 5.58s
# 992:	learn: 0.4784603	total: 11m 32s	remaining: 4.88s
# 993:	learn: 0.4784602	total: 11m 33s	remaining: 4.18s
# 994:	learn: 0.4784601	total: 11m 33s	remaining: 3.48s
# 995:	learn: 0.4784600	total: 11m 34s	remaining: 2.79s
# 996:	learn: 0.4784598	total: 11m 35s	remaining: 2.09s
# 997:	learn: 0.4784597	total: 11m 35s	remaining: 1.39s
# 998:	learn: 0.4784595	total: 11m 36s	remaining: 697ms
# 999:	learn: 0.4784593	total: 11m 37s	remaining: 0us
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14808/1348545040.py in <module>
#      15 # Evaluate the performance of the model
#      16 mse = mean_squared_error(y_test, y_pred)
# ---> 17 rmse = np.sqrt(mse)
#      18 print(f"RMSE: {rmse:.2f}")
#
# NameError: name 'np' is not defined

# %%
import numpy as np
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 0.48

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# 모델 성능 평가

MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
R2 = r2_score(y_test, y_pred)
ensemble_score = pd.DataFrame({"ensemble_model" : [MAE, MSE, R2]}, index = ['MAE', 'MSE', 'R2'])
ensemble_score
# Out:
#      ensemble_model
# MAE        0.457773
# MSE        0.228470
# R2         0.004588

# %%
model=LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
X_val = data2.drop(['IsCorrect'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14808/4230088744.py in <module>
# ----> 1 X_val = data2.drop(['IsCorrect'],axis=1)
#
# NameError: name 'data2' is not defined

# %%
y_pred_val = model.predict(X_val)

# %%
accuracy_val = accuracy_score(y_val, y_pred_val)
print("Validation Accuracy:", accuracy_val)
# Out:
# Validation Accuracy: 0.606702559792607

# %%
y_test_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0.61541259, 0.61076922, 0.6253161 , ..., 0.66302698, 0.59897   ,
#        0.61220204])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#train_data2 = pd.read_csv('train_data/train_task_1_2.csv')

# %%
public_data2 = pd.read_csv('data/test_data/test_public_answers_task_2.csv')
test_data2 = pd.read_csv('data/test_data/test_private_answers_task_2.csv')

# %%
train_data1.head()
# Out:
#    QuestionId  UserId  AnswerId  IsCorrect  CorrectAnswer  AnswerValue
# 0       16997   65967  12453206          0              4            2
# 1       16531   62121  15686710          1              1            1
# 2       15911   50013  13598796          0              3            1
# 3        1701  104909  10511925          0              4            3
# 4       22896   21748    941747          0              1            4

# %%
public_data2.head()
# Out:
#    QuestionId  UserId  AnswerId  AnswerValue
# 0       10856    5518   1127409            1
# 1       14766   41565  19673056            4
# 2        2829   97267  19426951            4
# 3       26464  100879   4929721            2
# 4       24436   87722   2927607            3

# %%
X_train2 = train_data1[['QuestionId', 'UserId', 'AnswerId']] 
y_train2 = train_data1['AnswerValue']

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier()

# %%
X_val2 = public_data2[['QuestionId', 'UserId', 'AnswerId']]
y_val_pred2 = model.predict(X_val2)

# %%
X_test2 = test_data2[['QuestionId', 'UserId', 'AnswerId']]
y_test_pred2 = model.predict(X_test2)

# %%
print("Validation Predictions:")
print(y_val_pred2)
# Out:
# Validation Predictions:
# [1 4 3 ... 3 2 2]

# %%
print("Test Predictions:")
print(y_test_pred2)
# Out:
# Test Predictions:
# [4 1 1 ... 1 4 3]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_test2 = test_data2['AnswerValue']
MAE = mean_absolute_error(y_test2, y_test_pred2)
MSE = mean_squared_error(y_test2, y_test_pred2)
R2 = r2_score(y_test2, y_test_pred2)
score = pd.DataFrame({"model#2" : [MAE, MSE, R2]}, index = ['MAE', 'MSE', 'R2'])
score
# Out:
#       model#2
# MAE  0.827780
# MSE  1.613725
# R2  -0.345796

# %%
train_data3 = pd.read_csv('data/train_data/train_task_3_4.csv')
metadata_a = pd.read_csv('data/metadata/answer_metadata_task_3_4.csv')
metadata_s = pd.read_csv('data/metadata/student_metadata_task_3_4.csv')
metadata_q = pd.read_csv('data/metadata/question_metadata_task_3_4.csv')

# %%
metadata_a.head()
metadata_a.columns
# Out:
# Index(['AnswerId', 'DateAnswered', 'Confidence', 'GroupId', 'QuizId',
#        'SchemeOfWorkId'],
#       dtype='object')

# %%
metadata_s.head()
metadata_s.columns
# Out:
# Index(['UserId', 'Gender', 'DateOfBirth', 'PremiumPupil'], dtype='object')

# %%
metadata_q.columns
# Out:
# Index(['QuestionId', 'SubjectId'], dtype='object')

# %%
# Merge student metadata
train_data3 = pd.merge(train_data1, metadata_s, on='UserId', how='left')

# Merge question metadata
train_data3 = pd.merge(train_data1, metadata_q, on='QuestionId', how='left')

# Merge answer metadata
train_data3 = pd.merge(train_data1, metadata_a, on='AnswerId', how='left')

# %%
train_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15867850 entries, 0 to 15867849
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   QuestionId      int64
#  1   UserId          int64
#  2   AnswerId        int64
#  3   IsCorrect       int64
#  4   CorrectAnswer   int64
#  5   AnswerValue     int64
#  6   DateAnswered    object
#  7   Confidence      float64
#  8   GroupId         float64
#  9   QuizId          float64
#  10  SchemeOfWorkId  float64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 1.4+ GB

# %%
#train_data3['DateOfBirth'] = pd.to_datetime(train_data3['DateOfBirth'])
#train_data3['DateAnswered_x'] = pd.to_datetime(train_data3['DateAnswered_x'])
#train_data3['DateAnswered_y'] = pd.to_datetime(train_data3['DateAnswered_y'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DateAnswered_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14808/722211820.py in <module>
#       1 #train_data3['DateOfBirth'] = pd.to_datetime(train_data3['DateOfBirth'])
# ----> 2 train_data3['DateAnswered_x'] = pd.to_datetime(train_data3['DateAnswered_x'])
#       3 train_data3['DateAnswered_y'] = pd.to_datetime(train_data3['DateAnswered_y'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'DateAnswered_x'

# %%
train_data3['PremiumPupil'] = train_data3['PremiumPupil'].fillna(0)

# Drop rows with missing values in DateOfBirth column
train_data3 = train_data3.dropna(subset=['DateOfBirth'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PremiumPupil'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14808/4104219935.py in <module>
# ----> 1 train_data3['PremiumPupil'] = train_data3['PremiumPupil'].fillna(0)
#       2
#       3 # Drop rows with missing values in DateOfBirth column
#       4 train_data3 = train_data3.dropna(subset=['DateOfBirth'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'PremiumPupil'

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_data3['SubjectId'] = label_encoder.fit_transform(train_data3['SubjectId'])

# %%
train_data3 = train_data3.drop(['DateAnswered_x', 'DateAnswered_y'], axis=1)
train_data3['Gender'] = train_data3['Gender'].astype('category')

# %%
train_data3['GroupId_y'] = train_data3['GroupId_y'].astype(str)
train_data3['QuizId_y'] = train_data3['QuizId_y'].astype(str)

# %%
train_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 727345 entries, 0 to 727344
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   QuestionId        727345 non-null  int64
#  1   UserId            727345 non-null  int64
#  2   AnswerId          727345 non-null  int64
#  3   IsCorrect         727345 non-null  int64
#  4   CorrectAnswer     727345 non-null  int64
#  5   AnswerValue       727345 non-null  int64
#  6   Gender            727345 non-null  category
#  7   DateOfBirth       727345 non-null  datetime64[ns]
#  8   PremiumPupil      727345 non-null  float64
#  9   SubjectId         727345 non-null  int32
#  10  Confidence_x      180280 non-null  float64
#  11  GroupId_x         727345 non-null  int64
#  12  QuizId_x          727345 non-null  int64
#  13  SchemeOfWorkId_x  663548 non-null  float64
#  14  Confidence_y      180280 non-null  float64
#  15  GroupId_y         727345 non-null  object
#  16  QuizId_y          727345 non-null  object
#  17  SchemeOfWorkId_y  663548 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(5), int32(1), int64(8), object(2)
# memory usage: 97.8+ MB

# %%
correlation_matrix = train_data3.corr()
correlation_with_target = correlation_matrix['IsCorrect'].sort_values(ascending=False)

# %%
correlation_matrix
# Out:
#                   QuestionId    UserId  AnswerId  IsCorrect  CorrectAnswer  \
# QuestionId          1.000000 -0.000285  0.000312   0.028102       0.019836
# UserId             -0.000285  1.000000  0.001468  -0.000755       0.001337
# AnswerId            0.000312  0.001468  1.000000  -0.000611      -0.000492
# IsCorrect           0.028102 -0.000755 -0.000611   1.000000       0.003498
# CorrectAnswer       0.019836  0.001337 -0.000492   0.003498       1.000000
# AnswerValue         0.012379 -0.001833  0.000527  -0.054820       0.363604
# PremiumPupil       -0.000362  0.044314  0.000481  -0.093184      -0.000076
# SubjectId          -0.016474  0.003826  0.001368  -0.031186       0.060438
# Confidence_x        0.016173  0.026789  0.001766   0.267186       0.003359
# GroupId_x           0.000493  0.032963  0.000406   0.024746      -0.003358
# QuizId_x           -0.027963  0.003014 -0.000144  -0.022500      -0.006776
# SchemeOfWorkId_x   -0.003399 -0.002100  0.001481  -0.001052      -0.002514
# Confidence_y        0.016173  0.026789  0.001766   0.267186       0.003359
# SchemeOfWorkId_y   -0.003399 -0.002100  0.001481  -0.001052      -0.002514
#
#                   AnswerValue  PremiumPupil  SubjectId  Confidence_x  \
# QuestionId           0.012379     -0.000362  -0.016474      0.016173
# UserId              -0.001833      0.044314   0.003826      0.026789
# AnswerId             0.000527      0.000481   0.001368      0.001766
# IsCorrect           -0.054820     -0.093184  -0.031186      0.267186
# CorrectAnswer        0.363604     -0.000076   0.060438      0.003359
# AnswerValue          1.000000      0.013177   0.009400     -0.020900
# PremiumPupil         0.013177      1.000000  -0.007377     -0.078260
# SubjectId            0.009400     -0.007377   1.000000      0.040314
# Confidence_x        -0.020900     -0.078260   0.040314      1.000000
# GroupId_x           -0.001760     -0.089415  -0.031120     -0.000006
# QuizId_x             0.002235     -0.000417   0.242265      0.024572
# SchemeOfWorkId_x    -0.000334     -0.001858   0.003791           NaN
# Confidence_y        -0.020900     -0.078260   0.040314      1.000000
# SchemeOfWorkId_y    -0.000334     -0.001858   0.003791           NaN
#
#                   GroupId_x  QuizId_x  SchemeOfWorkId_x  Confidence_y  \
# QuestionId         0.000493 -0.027963         -0.003399      0.016173
# UserId             0.032963  0.003014         -0.002100      0.026789
# AnswerId           0.000406 -0.000144          0.001481      0.001766
# IsCorrect          0.024746 -0.022500         -0.001052      0.267186
# CorrectAnswer     -0.003358 -0.006776         -0.002514      0.003359
# AnswerValue       -0.001760  0.002235         -0.000334     -0.020900
# PremiumPupil      -0.089415 -0.000417         -0.001858     -0.078260
# SubjectId         -0.031120  0.242265          0.003791      0.040314
# Confidence_x      -0.000006  0.024572               NaN      1.000000
# GroupId_x          1.000000  0.023945         -0.002461     -0.000006
# QuizId_x           0.023945  1.000000         -0.002012      0.024572
# SchemeOfWorkId_x  -0.002461 -0.002012          1.000000           NaN
# Confidence_y      -0.000006  0.024572               NaN      1.000000
# SchemeOfWorkId_y  -0.002461 -0.002012          1.000000           NaN
#
#                   SchemeOfWorkId_y
# QuestionId               -0.003399
# UserId                   -0.002100
# AnswerId                  0.001481
# IsCorrect                -0.001052
# CorrectAnswer            -0.002514
# AnswerValue              -0.000334
# PremiumPupil             -0.001858
# SubjectId                 0.003791
# Confidence_x                   NaN
# GroupId_x                -0.002461
# QuizId_x                 -0.002012
# SchemeOfWorkId_x          1.000000
# Confidence_y                   NaN
# SchemeOfWorkId_y          1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# load evaluators' score on "validation" set
eval_validation = pd.read_csv('test_data/quality_response_remapped_public.csv')
print(len(eval_validation))
eval_validation.head()
# Out:
# 25
#    Unnamed: 0  Unnamed: 0.1  left  right  T1_ALR  T2_CL  T3_GF  T4_MQ  T5_NS
# 0           0             0   909    318       2      2      2    1.0      2
# 1          16            16   285    609       2      2      2    2.0      2
# 2          48            48   132    271       1      2      2    2.0      1
# 3          38            38   704    127       2      2      1    2.0      2
# 4          33            33    16    586       1      1      2    2.0      2

# %%
correlation_matrix2 = eval_validation.corr()
correlation_with_target = correlation_matrix['IsCorrect'].sort_values(ascending=False)

# %%
# take the average of 5 evaulators` scores
eval_validation['score'] = eval_validation.filter(regex='^T', axis = 1).mean(axis=1)
eval_validation['score'].hist()
eval_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    25 non-null     int64
#  1   Unnamed: 0.1  25 non-null     int64
#  2   left          25 non-null     int64
#  3   right         25 non-null     int64
#  4   T1_ALR        25 non-null     int64
#  5   T2_CL         25 non-null     int64
#  6   T3_GF         25 non-null     int64
#  7   T4_MQ         25 non-null     float64
#  8   T5_NS         25 non-null     int64
#  9   score         25 non-null     float64
#  10  preference    25 non-null     int32
# dtypes: float64(2), int32(1), int64(8)
# memory usage: 2.2 KB

# %%
# decide preference
import numpy as np
def calc_preference(scores):
    preference = np.ones(len(scores), dtype=int)

    idx_two = scores > 1.5
    preference[idx_two] = 2
    a = list(preference)
    return list(preference)

eval_validation['preference'] = calc_preference(eval_validation['score'])
eval_validation['preference'].hist()
# Out:
# <AxesSubplot:>

# %%
print(a)
# Out:
#                                      0
# QuestionId       QuestionId        1.0
# AnswerId         AnswerId          1.0
# SchemeOfWorkId_y SchemeOfWorkId_x  1.0
# Confidence_y     Confidence_y      1.0
#                  Confidence_x      1.0
# ...                                ...
# SchemeOfWorkId_x Confidence_y      NaN
# Confidence_y     SchemeOfWorkId_x  NaN
#                  SchemeOfWorkId_y  NaN
# SchemeOfWorkId_y Confidence_x      NaN
#                  Confidence_y      NaN
#
# [196 rows x 1 columns]

# %%
eval_test = pd.read_csv('test_data/quality_response_remapped_private.csv')
print(len(eval_test))
eval_test.head()
# Out:
# 25
#    Unnamed: 0  Unnamed: 0.1  left  right  T1_ALR  T2_CL  T3_GF  T4_MQ  T5_NS
# 0          15            15   145    762       2      2      2    2.0      2
# 1          31            31   307    208       1      1      1    2.0      1
# 2          25            25   278    195       1      1      1    1.0      1
# 3           3             3    13    153       2      2      2    2.0      2
# 4          40            40    23    100       2      1      1    1.0      1

# %%
# take the average of scores by 5 evaulators
eval_test['score'] = eval_test.filter(regex='^T', axis = 1).mean(axis=1)
eval_test['score'].hist()
eval_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    25 non-null     int64
#  1   Unnamed: 0.1  25 non-null     int64
#  2   left          25 non-null     int64
#  3   right         25 non-null     int64
#  4   T1_ALR        25 non-null     int64
#  5   T2_CL         25 non-null     int64
#  6   T3_GF         25 non-null     int64
#  7   T4_MQ         24 non-null     float64
#  8   T5_NS         25 non-null     int64
#  9   score         25 non-null     float64
# dtypes: float64(2), int64(8)
# memory usage: 2.1 KB

# %%
from itertools import combinations

# %%
train_data3.head()
# Out:
#    QuestionId  UserId  AnswerId  IsCorrect  CorrectAnswer  AnswerValue Gender  \
# 0         898    2111    280203          1              2            2      2
# 1         298    3912    578636          1              3            3      2
# 2         134    5163   1042162          0              1            2      1
# 3         840    3896    150788          0              1            2      2
# 4         264    5047     67204          1              3            3      2
#
#   DateOfBirth  PremiumPupil  SubjectId  Confidence_x  GroupId_x  QuizId_x  \
# 0  2007-09-01           0.0         29           NaN         95        86
# 1  2008-04-01           0.0         40           NaN        314        78
# 2  2008-07-01           0.0         22           NaN        163        46
# 3  2008-06-01           1.0          7           NaN        370        66
# 4  2007-12-01           0.0         55           NaN        254       105
#
#    SchemeOfWorkId_x  Confidence_y GroupId_y QuizId_y  SchemeOfWorkId_y
# 0           52562.0           NaN        95       86           52562.0
# 1           52562.0           NaN       314       78           52562.0
# 2           52562.0           NaN       163       46           52562.0
# 3           52562.0           NaN       370       66           52562.0
# 4           52562.0           NaN       254      105           52562.0

# %%
template = pd.read_csv('template.csv')
len(template)
# Out:
# 948

# %%
template.head()
# Out:
#    QuestionId  Ranking
# 0           0      NaN
# 1           1      NaN
# 2           2      NaN
# 3           3      NaN
# 4           4      NaN

# %%
template['ranking'] = 1

# %%
df = pd.read_csv('data/train_data/train_task_3_4.csv')

# %%
from sklearn.ensemble import RandomForestRegressor

X_train = df.drop(['QuestionId', 'IsCorrect'], axis=1) 
y_train = df['IsCorrect']

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [200, 300],
    'max_depth': [ 5, 10],
    'min_samples_split': [ 5, 10]
}
# Create the RandomForestRegressor model
model = RandomForestRegressor()

# Perform Grid Search with cross-validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
# Best Score: 0.7157555639881639

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor, LGBMClassifier, Booster
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, PoissonRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
parameters2 = {'n_estimators' : (200, 300, 400), 
              'learning_rate' : (0.05, 0.1, 0.2)}

# GridSearchCV를 통해 최적의 하이퍼 파라미터 찾기
reg2 = GridSearchCV(lgb_model, parameters2, cv = 3, n_jobs = -1, verbose = 2)

# cross validation 조각 3개
reg2.fit(X_train, y_train)  
reg2.best_estimator_
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# LGBMRegressor(learning_rate=0.2, n_estimators=400, random_state=42)

# %%
# Initialize the individual models
lasso_model = Lasso(alpha = 0.001, random_state = 1)
rf_model = RandomForestRegressor(max_depth=12,random_state = 42)
lgb_model = lgb.LGBMRegressor(learning_rate=0.2,n_estimators = 400, random_state = 42)

# Initialize the ensemble model
ensemble_model3 = VotingRegressor(estimators=[("lasso", lasso_model), ("rf", rf_model), ("lgb", lgb_model)])

# Fit the ensemble model to the scaled training data
ensemble_model3.fit(X_train, y_train)

# Make predictions on the scaled testing data
y_pred = ensemble_model3.predict(X_train)

# %%
model = RandomForestRegressor(max_depth= 10, min_samples_split= 5, n_estimators= 200)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, n_estimators=200)

# %%
y_pred2 = ensemble_model3.predict(X_train)
y_pred2
# Out:
# array([0.76640452, 0.76025743, 0.76612615, ..., 0.85349671, 0.17039047,
#        0.76050991])

# %%
y_pred
# Out:
# array([0.75321604, 0.75329486, 0.75321604, ..., 1.        , 0.        ,
#        0.75329486])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

MAE = mean_absolute_error(y_train, y_pred)
MSE = mean_squared_error(y_train, y_pred)
R2 = r2_score(y_train, y_pred)
score = pd.DataFrame({"model_for_result" : [MAE, MSE, R2]}, index = ['MAE', 'MSE', 'R2'])
score
# Out:
#      model_for_result
# MAE          0.146891
# MSE          0.073278
# R2           0.705245

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

MAE = mean_absolute_error(y_train, y_pred2)
MSE = mean_squared_error(y_train, y_pred2)
R2 = r2_score(y_train, y_pred2)
score = pd.DataFrame({"model_for_result" : [MAE, MSE, R2]}, index = ['MAE', 'MSE', 'R2'])
score
# Out:
#      model_for_result
# MAE          0.213945
# MSE          0.051825
# R2           0.791536

# %%
submission_df = df[['QuestionId']].copy()
submission_df['score'] = y_pred2

# %%
submission_df.sort_values(by='score', ascending=False, inplace=True)
submission_df.drop_duplicates(subset='QuestionId', keep='first', inplace=True)
submission_df['rank'] = range(1, len(submission_df) + 1)

# %%
print(submission_df[['QuestionId', 'rank']])
# Out:
#          QuestionId  rank
# 537470          516     1
# 575906          523     2
# 748117          457     3
# 503072          314     4
# 563013          463     5
# ...             ...   ...
# 847052          841   944
# 1228968         108   945
# 754404          139   946
# 748560          244   947
# 566817          548   948
#
# [948 rows x 2 columns]

# %%
def evaluate(truth, submission):
    submission_preference = []
    for idx, row in truth.iterrows():
        left_question_id = row['left']
        right_question_id = row['right']
        left_rank = submission.loc[submission['QuestionId'] == left_question_id, 'rank'].values[0]
        right_rank = submission.loc[submission['QuestionId'] == right_question_id, 'rank'].values[0]
        
        preference = 1 if left_rank < right_rank else 2
        submission_preference.append(preference)
    
    return submission_preference
